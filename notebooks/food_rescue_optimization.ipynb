# %%
using CSV
using DataFrames

using JuMP
using Gurobi

using LinearAlgebra
using Statistics
using Random
Random.seed!(42)  # For reproducibility
# Out:
# TaskLocalRNG()

# %% [markdown]
# ## Import data

# %%
# Paths (relative to notebook structure)
restaurant_path    = "../clean_data/restaurant_data_expanded.csv"
scrap_path         = "../clean_data/food_scrap_locations.csv"
neighborhood_path  = "../clean_data/neighborhood_supply.csv"

# Read CSVs into DataFrames
food_scrap_locations  = CSV.read(scrap_path, DataFrame)
neighborhood_supply   = CSV.read(neighborhood_path, DataFrame)
restaurant_data       = CSV.read(restaurant_path, DataFrame)
restaurant_data = restaurant_data[shuffle(1:nrow(restaurant_data))[1:1000], :]

# Verify
println("Sampled restaurants: ", nrow(restaurant_data))
println("Total supply: ", sum(restaurant_data.waste) / 1e6, " million lbs")
# Out:
# Sampled restaurants: 1000
# Total supply: 75.08486887683786 million lbs

# %% [markdown]
# # Clean the data:
#
# ## Ensure no commas in numbers, each field cast as correct data type, drop unnecessary columns, and no negative supply from synthetic data

# %%
# ================================
# 3. CLEAN RESTAURANT
# ================================
# Columns: latitude | longitude | waste
rename!(restaurant_data, names(restaurant_data)[3] => :supply)

# Ensure Float64
restaurant_data.supply    = Float64.(restaurant_data.supply)
restaurant_data.latitude  = Float64.(restaurant_data.latitude)
restaurant_data.longitude = Float64.(restaurant_data.longitude)

# *** DROP RESTAURANTS WITH NEGATIVE SUPPLY ***
filter!(row -> row.supply >= 0, restaurant_data)



# ================================
# 3. CLEAN FOOD SCRAP CENTER DATA
# ================================
# rename Latitude and Longitude to latitude and longitude for consistency
rename!(food_scrap_locations, names(food_scrap_locations)[15] => :latitude)
rename!(food_scrap_locations, names(food_scrap_locations)[16] => :longitude)

# Keep only coordinates we need
food_scrap_locations.latitude = Float64.(food_scrap_locations.latitude)
food_scrap_locations.longitude = Float64.(food_scrap_locations.longitude)

# Keep only coordinate columns in food_scrap_locations
select!(food_scrap_locations, [:latitude, :longitude])

# ================================
# 4. CLEAN NEIGHBORHOOD SUPPLY DATA
# ================================
# Rename demand column for clarity
rename!(neighborhood_supply, names(neighborhood_supply)[4] => :supply_gap)

# Now neighborhood_supply.supply_gap might be String OR Float64.
# Only do replace/parse if it's strings.
if eltype(neighborhood_supply.supply_gap) <: AbstractString
    neighborhood_supply.supply_gap =
        parse.(Float64, replace.(neighborhood_supply.supply_gap, "," => ""))
end

# Demand = positive deficit, surplus -> 0
neighborhood_supply.demand = max.(0.0, -neighborhood_supply.supply_gap)

neighborhood_supply.latitude  = Float64.(neighborhood_supply.latitude)
neighborhood_supply.longitude = Float64.(neighborhood_supply.longitude)

# keep only necessary columns from neighborhood supply
select!(neighborhood_supply, [:latitude, :longitude, :demand, :Year])

# ================================
# 5. SHOW CLEANED HEADS
# ================================
println("=== Restaurants (cleaned) ===")
println(first(restaurant_data, 5))

println("\n=== Food Scrap Locations (cleaned) ===")
println(first(food_scrap_locations, 5))

println("\n=== Neighborhood Supply (cleaned) ===")
println(first(neighborhood_supply, 5))
# Out:
# === Restaurants (cleaned) ===
# 5×3 DataFrame
#  Row │ latitude  longitude  supply
#      │ Float64   Float64    Float64
# ─────┼────────────────────────────────────
#    1 │  40.7424   -73.9943      1.11117e5
#    2 │  40.7323   -73.8722  71532.9
#    3 │  40.7794   -73.9492  98561.5
#    4 │  40.6102   -73.9208  19103.5
#    5 │  40.7315   -73.861   94690.4
#
# === Food Scrap Locations (cleaned) ===
# 5×2 DataFrame
#  Row │ latitude  longitude
#      │ Float64   Float64
# ─────┼─────────────────────
#    1 │  40.6355   -74.0228
#    2 │  40.7526   -73.969
#    3 │  40.7635   -74.0002
#    4 │  40.762    -73.9693
#    5 │  40.7174   -74.0108
#
# === Neighborhood Supply (cleaned) ===
# 5×4 DataFrame
#  Row │ latitude  longitude  demand     Year
#      │ Float64   Float64    Float64    Int64
# ─────┼───────────────────────────────────────
#    1 │  40.8267   -73.9217  1.02143e5   2025
#    2 │  40.8321   -73.8887  3.33493e5   2025
#    3 │  40.8016   -73.9374  0.0         2025
#    4 │  40.8469   -73.8918  1.13653e5   2025
#    5 │  40.6193   -73.9733  0.0         2025

# %% [markdown]
# ## Get vectors for supply[i] for all restaurants, demand[k] for all neighborhoods, and cij[i,j] and cjk[j,k] to plug directly into JuMP model

# %%
# ================
# 6. EXTRACT VECTORS
# ================
R = nrow(restaurant_data)
D = nrow(food_scrap_locations)
N = nrow(neighborhood_supply)

supply = restaurant_data.supply              # s_i
demand = neighborhood_supply.demand          # d_k

# ================
# 7. MANHATTAN DISTANCE FUNCTION
# ================
manhattan(lat1, lon1, lat2, lon2) = abs(lat1 - lat2) + abs(lon1 - lon2)

# ================
# 8. COST MATRICES
# ================
# cij: Restaurants (i) → Donation centers (j)
cij = [manhattan(restaurant_data.latitude[i], restaurant_data.longitude[i],
                 food_scrap_locations.latitude[j], food_scrap_locations.longitude[j])
       for i in 1:R, j in 1:D]

# cjk: Donation centers (j) → Neighborhoods (k)
cjk = [manhattan(food_scrap_locations.latitude[j], food_scrap_locations.longitude[j],
                 neighborhood_supply.latitude[k], neighborhood_supply.longitude[k])
       for j in 1:D, k in 1:N]

println("Size of cij (R x D): ", size(cij))
println("Size of cjk (D x N): ", size(cjk))
# Out:
# Size of cij (R x D): (1000, 201)
# Size of cjk (D x N): (201, 591)

# %% [markdown]
# # Sanity check data

# %%
println("Demand: min = ", minimum(demand), ", max = ", maximum(demand))
println("Any NaN in demand? ", any(isnan.(demand)))
println("Any Inf in demand? ", any(isinf.(demand)))

println("Any NaN in cij? ", any(isnan.(cij)))
println("Any Inf in cij? ", any(isinf.(cij)))

println("Any NaN in cjk? ", any(isnan.(cjk)))
println("Any Inf in cjk? ", any(isinf.(cjk)))
# Out:
# Demand: min = 0.0, max = 4.27814874096381e6
# Any NaN in demand? false
# Any Inf in demand? false
# Any NaN in cij? false
# Any Inf in cij? false
# Any NaN in cjk? false
# Any Inf in cjk? false

# %%
R = nrow(restaurant_data)
D = nrow(food_scrap_locations)
N = nrow(neighborhood_supply)

println("R, D, N = ", (R, D, N))
# Out:
# R, D, N = (1000, 201, 591)

# %%
println("Size of cij: ", size(cij))  # should be (R, D)
println("Size of cjk: ", size(cjk))  # should be (D, N)
# Out:
# Size of cij: (1000, 201)
# Size of cjk: (201, 591)

# %% [markdown]
# # Cost-Reduction Optimization Model
#
# We formulate the minimum-cost redistribution problem below.
#
# **Sets**
#
# - $R$: restaurants (supply nodes)
# - $D$: food scrap / donation centers (transshipment nodes)
# - $N$: neighborhoods (demand nodes)
#
# **Parameters**
#
# - $s_i$: supply at restaurant $i \in R$
# - $d_k$: demand at neighborhood $k \in N$
# - $c_{ij}$: cost of transporting one unit from restaurant $i$ to donation center $j$
# - $c_{jk}$: cost of transporting one unit from donation center $j$ to neighborhood $k$
# - $M$: large penalty coefficient for unmet demand
#
# **Decision Variables**
#
# - $x_{ij} \ge 0$: shipment from restaurant $i$ to donation center $j$
# - $y_{jk} \ge 0$: shipment from donation center $j$ to neighborhood $k$
# - $u_k \ge 0$: unmet demand at neighborhood $k$
#
# ---
#
# ### **Objective: Minimize Total Cost**
#
# $ \displaystyle
# \min\;
# \sum_{i \in R} \sum_{j \in D} c_{ij} x_{ij}
# \;+\;
# \sum_{j \in D} \sum_{k \in N} c_{jk} y_{jk}
# \;+\;
# M \sum_{k \in N} u_k
# $
#
# ---
#
# ### **Constraints**
#
# **1. Restaurant supply limits**
#
# $ \displaystyle
# \sum_{j \in D} x_{ij} \le s_i \quad \forall i \in R
# $
#
# **2. Neighborhood demand balance**
#
# $ \displaystyle
# \sum_{j \in D} y_{jk} + u_k = d_k \quad \forall k \in N
# $
#
# **3. Flow conservation at donation centers**
#
# $ \displaystyle
# \sum_{k \in N} y_{jk}
# =
# \sum_{i \in R} x_{ij}
# \quad \forall j \in D
# $
#
# **4. Nonnegativity**
#
# $ \displaystyle x_{ij},\; y_{jk},\; u_k \ge 0 $

# %%
println("Any supply < 0? ", any(supply .< 0))
println("Any demand < 0? ", any(demand .< 0))
println("Any NaN in supply? ", any(isnan.(supply)))
println("Any NaN in demand? ", any(isnan.(demand)))
# Out:
# Any supply < 0? false
# Any demand < 0? false
# Any NaN in supply? false
# Any NaN in demand? false

# %%
# ================================
# 9. REDUCED COST OPTIMIZATION MODEL
# ================================

# Big-M penalty for unmet demand
# Here we pick M as the total demand so that leaving demand unmet is very expensive
M = sum(demand)

model_cost = Model(Gurobi.Optimizer)

set_silent(model_cost)

# Decision variables:
# x[i,j] = flow of food from restaurant i to donation center j
# y[j,k] = flow of food from donation center j to neighborhood k
# u[k]   = unmet demand at neighborhood k
@variable(model_cost, x[1:R, 1:D] >= 0)
@variable(model_cost, y[1:D, 1:N] >= 0)
@variable(model_cost, u[1:N] >= 0)

# Objective:
# Minimize transportation cost + big-M penalty on unmet demand
@objective(model_cost, Min,
    sum(cij[i,j] * x[i,j] for i in 1:R, j in 1:D) +
    sum(cjk[j,k] * y[j,k] for j in 1:D, k in 1:N) +
    M * sum(u[k] for k in 1:N)
)

# Constraints:

# 1) Restaurant supply: cannot ship more than available surplus
@constraint(model_cost, [i in 1:R],
    sum(x[i,j] for j in 1:D) <= supply[i]
)

# 2) Neighborhood demand balance:
#    inflow from centers + unmet demand = demand
@constraint(model_cost, [k in 1:N],
    sum(y[j,k] for j in 1:D) + u[k] == demand[k]
)

# 3) Donation centers are pure transshipment nodes:
#    total inflow from restaurants = total outflow to neighborhoods
@constraint(model_cost, [j in 1:D],
    sum(y[j,k] for k in 1:N) == sum(x[i,j] for i in 1:R)
)

# ================================
# 10. SOLVE AND INSPECT
# ================================
optimize!(model_cost)

total_demand   = sum(demand)
total_received = sum(value.(y))   # sum over all j,k
total_unmet    = sum(value.(u))   # sum over all k

reduction_abs = total_received
reduction_pct = 100 * reduction_abs / total_demand

println("Termination status: ", termination_status(model_cost))
println("Objective value (total cost + penalty): ", objective_value(model_cost))
println("Total neighborhood demand: ", total_demand)
println("Total received by neighborhoods: ", total_received)
println("Total unmet demand: ", total_unmet)
println("Demand reduction (absolute): ", reduction_abs)
println("Demand reduction (%): ", reduction_pct, "%")

# After optimize!(model_cost)

# Per-neighborhood received under COST model
r_cost = [sum(value.(y[j, k]) for j in 1:D) for k in 1:N]

println("=== Neighborhoods That Received Food ===\n")

count_nonzero_cost = 0
for k in 1:N
    if r_cost[k] > 0
        count_nonzero_cost += 1
        println("Neighborhood $(k): received $(round(r_cost[k], digits=2)) pounds")
    end
end

println("\nTotal neighborhoods receiving any food: $count_nonzero_cost")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Termination status: OPTIMAL
# Objective value (total cost + penalty): 1.179186228254354e16
# Total neighborhood demand: 1.5243933021550444e8
# Total received by neighborhoods: 7.508486887683785e7
# Total unmet demand: 7.73544613386666e7
# Demand reduction (absolute): 7.508486887683785e7
# Demand reduction (%): 49.25557516599548%
# === Neighborhoods That Received Food ===
#
# Neighborhood 1: received 102142.62 pounds
# Neighborhood 2: received 333492.65 pounds
# Neighborhood 4: received 113652.81 pounds
# Neighborhood 8: received 113911.46 pounds
# Neighborhood 20: received 23547.32 pounds
# Neighborhood 28: received 267239.25 pounds
# Neighborhood 33: received 1.18393395e6 pounds
# Neighborhood 40: received 40369.71 pounds
# Neighborhood 50: received 105498.51 pounds
# Neighborhood 56: received 979114.69 pounds
# Neighborhood 59: received 23285.42 pounds
# Neighborhood 80: received 238489.99 pounds
# Neighborhood 93: received 89959.74 pounds
# Neighborhood 101: received 704873.88 pounds
# Neighborhood 111: received 258687.53 pounds
# Neighborhood 114: received 16549.04 pounds
# Neighborhood 115: received 175960.45 pounds
# Neighborhood 118: received 261754.51 pounds
# Neighborhood 120: received 405519.22 pounds
# Neighborhood 124: received 2162.6 pounds
# Neighborhood 126: received 200353.6 pounds
# Neighborhood 129: received 509804.84 pounds
# Neighborhood 135: received 363136.01 pounds
# Neighborhood 147: received 272014.5 pounds
# Neighborhood 155: received 720808.95 pounds
# Neighborhood 156: received 2.50267088e6 pounds
# Neighborhood 158: received 605451.43 pounds
# Neighborhood 163: received 105866.87 pounds
# Neighborhood 166: received 1.81843204e6 pounds
# Neighborhood 168: received 2.09885694e6 pounds
# Neighborhood 172: received 978735.2 pounds
# Neighborhood 174: received 779229.04 pounds
# Neighborhood 175: received 985286.69 pounds
# Neighborhood 179: received 268423.63 pounds
# Neighborhood 182: received 3.27272507e6 pounds
# Neighborhood 191: received 2.28344722e6 pounds
# Neighborhood 194: received 311007.77 pounds
# Neighborhood 197: received 797194.91 pounds
# Neighborhood 203: received 13128.31 pounds
# Neighborhood 207: received 2.46610213e6 pounds
# Neighborhood 209: received 373365.51 pounds
# Neighborhood 210: received 286612.13 pounds
# Neighborhood 214: received 666044.62 pounds
# Neighborhood 221: received 404200.91 pounds
# Neighborhood 222: received 56409.56 pounds
# Neighborhood 223: received 560298.34 pounds
# Neighborhood 236: received 424811.03 pounds
# Neighborhood 237: received 509307.12 pounds
# Neighborhood 242: received 2.2632048e6 pounds
# Neighborhood 244: received 737793.87 pounds
# Neighborhood 245: received 1.04713999e6 pounds
# Neighborhood 246: received 1.37776219e6 pounds
# Neighborhood 247: received 1.15737126e6 pounds
# Neighborhood 252: received 1.57633239e6 pounds
# Neighborhood 253: received 690257.6 pounds
# Neighborhood 254: received 1.46609475e6 pounds
# Neighborhood 255: received 2.03696497e6 pounds
# Neighborhood 269: received 130707.95 pounds
# Neighborhood 277: received 88214.41 pounds
# Neighborhood 313: received 1.23241672e6 pounds
# Neighborhood 319: received 624041.39 pounds
# Neighborhood 324: received 3.54929376e6 pounds
# Neighborhood 325: received 129753.36 pounds
# Neighborhood 326: received 104606.61 pounds
# Neighborhood 327: received 557994.27 pounds
# Neighborhood 336: received 481957.93 pounds
# Neighborhood 346: received 311932.67 pounds
# Neighborhood 355: received 196114.86 pounds
# Neighborhood 371: received 229413.33 pounds
# Neighborhood 379: received 237746.9 pounds
# Neighborhood 380: received 373991.07 pounds
# Neighborhood 381: received 124780.28 pounds
# Neighborhood 384: received 264545.46 pounds
# Neighborhood 400: received 82217.31 pounds
# Neighborhood 401: received 225650.67 pounds
# Neighborhood 402: received 904474.36 pounds
# Neighborhood 404: received 1.17085996e6 pounds
# Neighborhood 417: received 255191.16 pounds
# Neighborhood 434: received 77079.76 pounds
# Neighborhood 439: received 1.88955793e6 pounds
# Neighborhood 441: received 156023.38 pounds
# Neighborhood 442: received 810537.52 pounds
# Neighborhood 443: received 575068.83 pounds
# Neighborhood 444: received 319917.59 pounds
# Neighborhood 445: received 586280.14 pounds
# Neighborhood 447: received 348421.12 pounds
# Neighborhood 449: received 1.54032922e6 pounds
# Neighborhood 450: received 882935.48 pounds
# Neighborhood 451: received 1.18576355e6 pounds
# Neighborhood 452: received 1.73749145e6 pounds
# Neighborhood 474: received 478056.68 pounds
# Neighborhood 479: received 196019.04 pounds
# Neighborhood 493: received 311334.06 pounds
# Neighborhood 496: received 34734.24 pounds
# Neighborhood 507: received 8538.37 pounds
# Neighborhood 510: received 441461.4 pounds
# Neighborhood 516: received 180238.28 pounds
# Neighborhood 521: received 1.39268179e6 pounds
# Neighborhood 522: received 89791.06 pounds
# Neighborhood 523: received 1.00167224e6 pounds
# Neighborhood 526: received 164804.51 pounds
# Neighborhood 527: received 1.10132634e6 pounds
# Neighborhood 529: received 2.2635378e6 pounds
# Neighborhood 532: received 209126.85 pounds
# Neighborhood 533: received 527148.97 pounds
# Neighborhood 543: received 309269.1 pounds
# Neighborhood 549: received 366522.63 pounds
# Neighborhood 551: received 25318.04 pounds
# Neighborhood 552: received 121379.77 pounds
# Neighborhood 560: received 36052.64 pounds
# Neighborhood 577: received 1.26667925e6 pounds
# Neighborhood 581: received 709989.79 pounds
# Neighborhood 585: received 37083.23 pounds
#
# Total neighborhoods receiving any food: 113

# %% [markdown]
# ## Equity objective: minimizing worst unmet demand
#
# We now consider an **equity-focused** objective that tries to avoid leaving any neighborhood with a very large unmet demand. Instead of minimizing total cost, we minimize the **maximum unmet demand** across neighborhoods.
#
# ### Sets
#
# - $R$: set of restaurants, indexed by $i$
# - $D$: set of food scrap centers, indexed by $j$
# - $N$: set of neighborhoods, indexed by $k$
#
# ### Parameters
#
# - $s_i$: supply (surplus food) at restaurant $i \in R$
# - $d_k$: demand (food needed) in neighborhood $k \in N$
#
# ### Decision variables
#
# - $x_{ij} \ge 0$: amount shipped from restaurant $i$ to donation center $j$
# - $y_{jk} \ge 0$: amount shipped from donation center $j$ to neighborhood $k$
# - $r_k$: food received by neighborhood $k$
# - $t$: upper bound on unmet demand across all neighborhoods
#
# ### Equity optimization problem
#
# We minimize the worst (largest) unmet demand:
#
# $ \min \ t $
#
# subject to:
#
# $ \sum_{j \in D} x_{ij} \le s_i \quad \forall i \in R $  &nbsp; (restaurant supply)
#
# $ \sum_{k \in N} y_{jk} = \sum_{i \in R} x_{ij} \quad \forall j \in D $  &nbsp; (flow conservation at centers)
#
# $ r_k = \sum_{j \in D} y_{jk} \quad \forall k \in N $  &nbsp; (received by each neighborhood)
#
# $ r_k \le d_k \quad \forall k \in N $  &nbsp; (cannot exceed demand)
#
# $ t \ge d_k - r_k \quad \forall k \in N $  &nbsp; (unmet demand in each neighborhood)
#
# $ x_{ij}, \, y_{jk} \ge 0 $
#
# Interpretation:
# - $r_k$ captures how much food neighborhood $k$ actually receives._

# %%
# ================================
# Build index sets and parameters
# ================================

R = nrow(restaurant_data)          # number of restaurants
D = nrow(food_scrap_locations)     # number of food scrap centers
N = nrow(neighborhood_supply)      # number of neighborhoods

s = restaurant_data.supply         # s_i: supply at restaurant i
d = neighborhood_supply.demand     # d_k: demand at neighborhood k

# ================================
# Equity model: minimize worst unmet demand
# ================================
model_equity = Model(Gurobi.Optimizer)

set_silent(model_equity)

# Decision variables
@variable(model_equity, x[1:R, 1:D] >= 0)   # shipments restaurant -> center
@variable(model_equity, y[1:D, 1:N] >= 0)   # shipments center -> neighborhood
@variable(model_equity, r[1:N] >= 0)        # received by each neighborhood
@variable(model_equity, t >= 0)             # worst unmet demand across neighborhoods

# Objective: minimize worst unmet demand
@objective(model_equity, Min, t)

# 1) Restaurant supply: ∑_j x_ij ≤ s_i   ∀ i ∈ R
@constraint(model_equity, [i in 1:R],
    sum(x[i,j] for j in 1:D) <= s[i]
)

# 2) Flow conservation at centers:
#    ∑_k y_jk = ∑_i x_ij   ∀ j ∈ D
@constraint(model_equity, [j in 1:D],
    sum(y[j,k] for k in 1:N) == sum(x[i,j] for i in 1:R)
)

# 3) Neighborhood received:
#    r_k = ∑_j y_jk   ∀ k ∈ N
@constraint(model_equity, [k in 1:N],
    r[k] == sum(y[j,k] for j in 1:D)
)

# 4) Cannot exceed demand:
#    r_k ≤ d_k   ∀ k ∈ N
@constraint(model_equity, [k in 1:N],
    r[k] <= d[k]
)

# 5) Worst unmet demand:
#    t ≥ d_k - r_k   ∀ k ∈ N
@constraint(model_equity, [k in 1:N],
    t >= d[k] - r[k]
)

# ================================
# Solve and report
# ================================
optimize!(model_equity)

println("Equity model termination status: ", termination_status(model_equity))
println("Optimal worst unmet demand t*: ", value(t))

total_demand   = sum(d)
total_received = sum(value.(r))
total_unmet    = total_demand - total_received

println("Total demand:   ", total_demand)
println("Total received: ", total_received)
println("Total unmet:    ", total_unmet)
println("Demand reduction (%): ", 100 * total_received / total_demand, "%")


# Pull received amounts
r_vals = value.(r)

println("=== Neighborhoods That Received Food ===\n")

count_nonzero = 0
for k in 1:N
    if r_vals[k] > 0
        count_nonzero += 1
        println("Neighborhood $(k): received $(round(r_vals[k], digits=2)) units")
    end
end

println("\nTotal neighborhoods receiving any food: $count_nonzero")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Equity model termination status: OPTIMAL
# Optimal worst unmet demand t*: 721313.1739676003
# Total demand:   1.5243933021550444e8
# Total received: 7.508486887683785e7
# Total unmet:    7.735446133866659e7
# Demand reduction (%): 49.25557516599548%
# === Neighborhoods That Received Food ===
#
# Neighborhood 33: received 462620.77 units
# Neighborhood 56: received 257801.52 units
# Neighborhood 69: received 1.510081e6 units
# Neighborhood 129: received 2.21059569e6 units
# Neighborhood 140: received 780939.23 units
# Neighborhood 141: received 1.3419113e6 units
# Neighborhood 149: received 74288.42 units
# Neighborhood 156: received 1.7813577e6 units
# Neighborhood 162: received 487567.65 units
# Neighborhood 165: received 1.44824261e6 units
# Neighborhood 166: received 1.10169799e6 units
# Neighborhood 168: received 1.37754376e6 units
# Neighborhood 172: received 1.60768203e6 units
# Neighborhood 174: received 130971.39 units
# Neighborhood 175: received 263973.51 units
# Neighborhood 179: received 642928.24 units
# Neighborhood 182: received 2.5514119e6 units
# Neighborhood 183: received 1.84020332e6 units
# Neighborhood 188: received 10327.91 units
# Neighborhood 191: received 1.56213405e6 units
# Neighborhood 195: received 1.60872617e6 units
# Neighborhood 196: received 2.71591141e6 units
# Neighborhood 197: received 75881.73 units
# Neighborhood 207: received 1.74478895e6 units
# Neighborhood 210: received 445171.26 units
# Neighborhood 211: received 802310.05 units
# Neighborhood 214: received 157522.26 units
# Neighborhood 242: received 1.54189162e6 units
# Neighborhood 244: received 16480.7 units
# Neighborhood 245: received 325826.81 units
# Neighborhood 246: received 656449.02 units
# Neighborhood 247: received 436058.09 units
# Neighborhood 248: received 2.4611412e6 units
# Neighborhood 250: received 3.55683557e6 units
# Neighborhood 252: received 855019.21 units
# Neighborhood 254: received 744781.58 units
# Neighborhood 255: received 1.3156518e6 units
# Neighborhood 313: received 511103.54 units
# Neighborhood 324: received 2.82798058e6 units
# Neighborhood 352: received 2.71178793e6 units
# Neighborhood 363: received 1.277238e6 units
# Neighborhood 364: received 2.90286362e6 units
# Neighborhood 365: received 203882.25 units
# Neighborhood 366: received 412900.58 units
# Neighborhood 367: received 2.19381501e6 units
# Neighborhood 368: received 578128.55 units
# Neighborhood 371: received 909597.98 units
# Neighborhood 372: received 125557.46 units
# Neighborhood 373: received 570687.43 units
# Neighborhood 380: received 1.18011381e6 units
# Neighborhood 384: received 1132.78 units
# Neighborhood 402: received 183161.19 units
# Neighborhood 404: received 449546.79 units
# Neighborhood 407: received 95008.3 units
# Neighborhood 439: received 1.16824476e6 units
# Neighborhood 442: received 89224.35 units
# Neighborhood 445: received 1.29329691e6 units
# Neighborhood 447: received 2.02883287e6 units
# Neighborhood 449: received 819016.05 units
# Neighborhood 450: received 161622.31 units
# Neighborhood 451: received 464450.37 units
# Neighborhood 452: received 1.01617827e6 units
# Neighborhood 521: received 671368.62 units
# Neighborhood 523: received 280359.07 units
# Neighborhood 527: received 380013.17 units
# Neighborhood 529: received 1.54222463e6 units
# Neighborhood 549: received 1.74747456e6 units
# Neighborhood 560: received 1.1414518e6 units
# Neighborhood 561: received 2.16168496e6 units
# Neighborhood 564: received 1.27470926e6 units
# Neighborhood 568: received 260117.64 units
# Neighborhood 577: received 545366.07 units
#
# Total neighborhoods receiving any food: 72

# %% [markdown]
# ## Multi-Objective Optimization: Balancing Cost Reduction and Equity
#
# We now combine the two objectives studied earlier:
#
# 1. **Reduced Cost Objective** — minimize total transportation cost plus a large penalty on unmet demand.
# 2. **Equity Objective** — minimize the worst unmet demand across neighborhoods.
#
# These two goals can conflict:
# efficient routing can increase inequity, while equitable distribution can increase transportation cost.
#
# To explore the tradeoff, we form a **scalarized multi-objective**:
#
# $$
# \min \;
# w_{\text{cost}} \cdot \text{CostObjective}
# \;+\;
# w_{\text{eq}} \cdot \text{EquityObjective}.
# $$
#
# ### Cost objective component
#
# $$
# \text{CostObjective} =
# \sum_{i \in R} \sum_{j \in D} c_{ij} x_{ij}
# \;+\;
# \sum_{j \in D} \sum_{k \in N} c_{jk} y_{jk}
# \;+\;
# M \sum_{k \in N} u_k,
# $$
#
# where $u_k$ represents unmet demand in neighborhood $k$.
#
# ### Equity objective component
#
# The equity term is simply:
#
# $$
# \text{EquityObjective} = t,
# $$
#
# where $t$ is constrained so that:
#
# $$
# t \ge d_k - r_k \quad \forall k \in N.
# $$
#
# Thus, $t$ equals the **worst (maximum) unmet demand** across neighborhoods.
#
# ### Weight Sweep: $1{:}1$ through $1{:}10$ and back from $10{:}1$ to $2{:}1$
#
# To fully explore the continuum between efficiency and fairness, we solve the combined model under **19 weight pairs**, starting with:
#
# - $1{:}1, 1{:}2, \ldots, 1{:}10$  (equity increasingly emphasized)
#
# and then sweeping back:
#
# - $10{:}1, 9{:}1, \ldots, 2{:}1$  (cost increasingly emphasized)
#
# Formally, the set of weight pairs is:
#
# $$
# (w_{\text{cost}}, w_{\text{eq}}) \in
# \{(1,1), (1,2), \ldots, (1,10),
# \; (10,1), (9,1), \ldots, (2,1)\}.
# $$
#
# For each pair, we record:
#
# - total transportation cost
# - maximum unmet demand $t$
# - total food delivered
# - total unmet demand
# - which neighborhoods receive food
#
# This sweep traces out the **Pareto frontier** between cost reduction and equitable food distribution, revealing how solutions shift as we change the relative importance of the two objectives.

# %%
using JuMP
using Gurobi
using DataFrames

# Assume you already have:
# R, D, N
# supply (length R), demand (length N)
# cij[i,j], cjk[j,k]
# M defined (big-M for unmet demand)

function build_combined_model(w_cost::Float64, w_eq::Float64)
    model = Model(Gurobi.Optimizer)
    set_silent(model)

    # Decision variables
    @variable(model, x[1:R, 1:D] >= 0)   # restaurant -> center
    @variable(model, y[1:D, 1:N] >= 0)   # center -> neighborhood
    @variable(model, u[1:N] >= 0)        # unmet demand (for cost part)
    @variable(model, r[1:N] >= 0)        # received (for equity part)
    @variable(model, t >= 0)             # worst unmet demand

    # === Shared constraints ===

    # 1) Restaurant supply
    @constraint(model, [i in 1:R],
        sum(x[i,j] for j in 1:D) <= supply[i]
    )

    # 2) Flow conservation at centers
    @constraint(model, [j in 1:D],
        sum(y[j,k] for k in 1:N) == sum(x[i,j] for i in 1:R)
    )

    # 3) Demand balance for cost part:
    #    inflow + unmet = demand
    @constraint(model, [k in 1:N],
        sum(y[j,k] for j in 1:D) + u[k] == demand[k]
    )

    # 4) r_k = received = ∑_j y_jk
    @constraint(model, [k in 1:N],
        r[k] == sum(y[j,k] for j in 1:D)
    )

    # (optional, redundant but harmless) r_k ≤ d_k
    @constraint(model, [k in 1:N],
        r[k] <= demand[k]
    )

    # 5) Worst unmet demand: t ≥ d_k - r_k
    @constraint(model, [k in 1:N],
        t >= demand[k] - r[k]
    )

    # === Objective pieces ===

    @expression(model, cost_expr,
        sum(cij[i,j] * x[i,j] for i in 1:R, j in 1:D) +
        sum(cjk[j,k] * y[j,k] for j in 1:D, k in 1:N) +
        M * sum(u[k] for k in 1:N)
    )

    @expression(model, equity_expr, t)

    # Weighted objective: w_cost * cost + w_eq * equity
    @objective(model, Min, w_cost * cost_expr + w_eq * equity_expr)

    return model, x, y, u, r, t, cost_expr, equity_expr
end
# Out:
# build_combined_model (generic function with 1 method)

# %%
results = DataFrame(
    w_cost      = Float64[],
    w_eq        = Float64[],
    obj_value   = Float64[],
    cost_value  = Float64[],
    equity_t    = Float64[],
    total_recv  = Float64[],
    total_unmet = Float64[],
)

# 1:1, 1:2, ..., 1:10
for w_eq_int in 1:10
    w_cost = 1.0
    w_eq   = float(w_eq_int)   # convert Int -> Float64

    model, x, y, u, r, t, cost_expr, equity_expr = build_combined_model(w_cost, w_eq)
    optimize!(model)

    if termination_status(model) != MOI.OPTIMAL
        println("Weights (", w_cost, ", ", w_eq, ") not optimal, status = ", termination_status(model))
        continue
    end

    obj_val    = objective_value(model)
    cost_val   = value(cost_expr)
    t_val      = value(t)
    r_vals     = value.(r)
    u_vals     = value.(u)
    total_d    = sum(demand)
    total_recv = sum(r_vals)
    total_unm  = total_d - total_recv

    # transport cost (miles) = cost objective minus big-M penalty
    transport_cost = cost_val - M * sum(u_vals)

    # per-neighborhood remaining deficit
    unmet_by_k = demand .- r_vals
    max_unmet, worst_k = findmax(unmet_by_k)

    push!(results, (w_cost, w_eq, obj_val, cost_val, t_val, total_recv, total_unm))

    # === Print summary for this weight pair ===
    println("\n=== Weights: w_cost = $(w_cost), w_eq = $(w_eq) ===")
    println("Total miles driven (transport cost, no penalty): ",
            round(transport_cost, digits = 2))
    println("Worst remaining deficit: ",
            round(max_unmet, digits = 2),
            " units in neighborhood ", worst_k)

    println("\nNeighborhoods that received food:\n")

    count_nonzero = 0
    for k in 1:N
        if r_vals[k] > 1e-6  # small threshold to ignore numerical noise
            count_nonzero += 1
            println("  Neighborhood $(k): $(round(r_vals[k], digits=2)) units")
        end
    end

    println("\nTotal neighborhoods receiving any food: $count_nonzero\n")
end

# 10:1, 9:1, ..., 2:1
for w_cost_int in 10:-1:2
    w_eq   = 1.0
    w_cost = float(w_cost_int)   # convert Int -> Float64

    model, x, y, u, r, t, cost_expr, equity_expr = build_combined_model(w_cost, w_eq)
    optimize!(model)

    if termination_status(model) != MOI.OPTIMAL
        println("Weights (", w_cost, ", ", w_eq, ") not optimal, status = ", termination_status(model))
        continue
    end

    obj_val    = objective_value(model)
    cost_val   = value(cost_expr)
    t_val      = value(t)
    r_vals     = value.(r)
    u_vals     = value.(u)
    total_d    = sum(demand)
    total_recv = sum(r_vals)
    total_unm  = total_d - total_recv

    # transport cost (miles) = cost objective minus big-M penalty
    transport_cost = cost_val - M * sum(u_vals)

    # per-neighborhood remaining deficit
    unmet_by_k = demand .- r_vals
    max_unmet, worst_k = findmax(unmet_by_k)

    push!(results, (w_cost, w_eq, obj_val, cost_val, t_val, total_recv, total_unm))

    # === Print summary for this weight pair ===
    println("\n=== Weights: w_cost = $(w_cost), w_eq = $(w_eq) ===")
    println("Total miles driven (transport cost, no penalty): ",
            round(transport_cost, digits = 2))
    println("Worst remaining deficit: ",
            round(max_unmet, digits = 2),
            " units in neighborhood ", worst_k)

    println("\nNeighborhoods that received food:\n")

    count_nonzero = 0
    for k in 1:N
        if r_vals[k] > 1e-6
            count_nonzero += 1
            println("  Neighborhood $(k): $(round(r_vals[k], digits=2)) units")
        end
    end

    println("\nTotal neighborhoods receiving any food: $count_nonzero\n")
end

println("=== Summary table over all weights ===")
println(results)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 1.0, w_eq = 1.0 ===
# Total miles driven (transport cost, no penalty): 7.373734e6
# Worst remaining deficit: 2.01461008e6 units in neighborhood 250
#
# Neighborhoods that received food:
#
#   Neighborhood 1: 102142.62 units
#   Neighborhood 2: 333492.65 units
#   Neighborhood 4: 113652.81 units
#   Neighborhood 8: 113911.46 units
#   Neighborhood 20: 23547.32 units
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 1.18393395e6 units
#   Neighborhood 40: 40369.71 units
#   Neighborhood 50: 105498.51 units
#   Neighborhood 59: 23285.42 units
#   Neighborhood 69: 216784.09 units
#   Neighborhood 80: 238489.99 units
#   Neighborhood 93: 89959.74 units
#   Neighborhood 101: 704873.88 units
#   Neighborhood 111: 258687.53 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 118: 261754.51 units
#   Neighborhood 120: 405519.22 units
#   Neighborhood 129: 917298.78 units
#   Neighborhood 135: 363136.01 units
#   Neighborhood 141: 48614.39 units
#   Neighborhood 147: 272014.5 units
#   Neighborhood 155: 720808.95 units
#   Neighborhood 156: 2.50267088e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 163: 105866.87 units
#   Neighborhood 165: 154945.7 units
#   Neighborhood 166: 705230.37 units
#   Neighborhood 168: 2.09885694e6 units
#   Neighborhood 172: 314385.12 units
#   Neighborhood 174: 502559.5 units
#   Neighborhood 175: 964596.0 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 183: 546906.41 units
#   Neighborhood 191: 2.28344722e6 units
#   Neighborhood 195: 315429.26 units
#   Neighborhood 196: 1.4226145e6 units
#   Neighborhood 197: 797194.91 units
#   Neighborhood 203: 13128.31 units
#   Neighborhood 207: 2.46610213e6 units
#   Neighborhood 209: 373365.51 units
#   Neighborhood 221: 404200.91 units
#   Neighborhood 222: 56409.56 units
#   Neighborhood 223: 560298.34 units
#   Neighborhood 236: 424811.03 units
#   Neighborhood 237: 509307.12 units
#   Neighborhood 242: 2.2632048e6 units
#   Neighborhood 244: 737793.87 units
#   Neighborhood 246: 1.37776219e6 units
#   Neighborhood 248: 1.16784429e6 units
#   Neighborhood 250: 2.26353866e6 units
#   Neighborhood 252: 1.57633239e6 units
#   Neighborhood 253: 690257.6 units
#   Neighborhood 254: 1.46609475e6 units
#   Neighborhood 255: 2.03696497e6 units
#   Neighborhood 269: 130707.95 units
#   Neighborhood 277: 88214.41 units
#   Neighborhood 313: 1.23241672e6 units
#   Neighborhood 319: 624041.39 units
#   Neighborhood 324: 3.54929376e6 units
#   Neighborhood 325: 129753.36 units
#   Neighborhood 326: 104606.61 units
#   Neighborhood 327: 557994.27 units
#   Neighborhood 336: 481957.93 units
#   Neighborhood 352: 1.41849102e6 units
#   Neighborhood 364: 1.60956671e6 units
#   Neighborhood 367: 900518.11 units
#   Neighborhood 379: 237746.9 units
#   Neighborhood 380: 149210.5 units
#   Neighborhood 381: 124780.28 units
#   Neighborhood 384: 722445.96 units
#   Neighborhood 400: 82217.31 units
#   Neighborhood 401: 225650.67 units
#   Neighborhood 402: 904474.36 units
#   Neighborhood 404: 1.17085996e6 units
#   Neighborhood 417: 255191.16 units
#   Neighborhood 434: 77079.76 units
#   Neighborhood 439: 1.88955793e6 units
#   Neighborhood 441: 156023.38 units
#   Neighborhood 443: 575068.83 units
#   Neighborhood 447: 735535.97 units
#   Neighborhood 449: 1.54032922e6 units
#   Neighborhood 450: 882935.48 units
#   Neighborhood 451: 1.18576355e6 units
#   Neighborhood 452: 1.73749145e6 units
#   Neighborhood 474: 478056.68 units
#   Neighborhood 479: 196019.04 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 516: 180238.28 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 1.00167224e6 units
#   Neighborhood 526: 164804.51 units
#   Neighborhood 527: 1.10132634e6 units
#   Neighborhood 529: 2.2635378e6 units
#   Neighborhood 533: 527148.97 units
#   Neighborhood 549: 454177.66 units
#   Neighborhood 561: 868388.06 units
#   Neighborhood 581: 252089.29 units
#   Neighborhood 585: 37083.23 units
#
# Total neighborhoods receiving any food: 103
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 1.0, w_eq = 2.0 ===
# Total miles driven (transport cost, no penalty): 8.386632e6
# Worst remaining deficit: 1.34037731e6 units in neighborhood 69
#
# Neighborhoods that received food:
#
#   Neighborhood 1: 102142.62 units
#   Neighborhood 2: 321686.31 units
#   Neighborhood 4: 113652.81 units
#   Neighborhood 20: 23547.32 units
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 1.18393395e6 units
#   Neighborhood 40: 40369.71 units
#   Neighborhood 50: 105498.51 units
#   Neighborhood 59: 23285.42 units
#   Neighborhood 69: 891016.87 units
#   Neighborhood 80: 238489.99 units
#   Neighborhood 93: 89959.74 units
#   Neighborhood 101: 704873.88 units
#   Neighborhood 111: 258687.53 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 129: 1.59153155e6 units
#   Neighborhood 135: 363136.01 units
#   Neighborhood 140: 161875.1 units
#   Neighborhood 141: 722847.17 units
#   Neighborhood 147: 272014.5 units
#   Neighborhood 155: 54585.89 units
#   Neighborhood 156: 2.50267088e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 163: 105866.87 units
#   Neighborhood 165: 829178.48 units
#   Neighborhood 166: 482633.86 units
#   Neighborhood 168: 2.09885694e6 units
#   Neighborhood 172: 988617.89 units
#   Neighborhood 174: 502559.5 units
#   Neighborhood 179: 23864.1 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 183: 1.22113918e6 units
#   Neighborhood 191: 943069.91 units
#   Neighborhood 195: 989662.04 units
#   Neighborhood 196: 2.09684727e6 units
#   Neighborhood 197: 448536.73 units
#   Neighborhood 203: 13128.31 units
#   Neighborhood 207: 2.46610213e6 units
#   Neighborhood 209: 373365.51 units
#   Neighborhood 211: 183245.91 units
#   Neighborhood 221: 404200.91 units
#   Neighborhood 222: 56409.56 units
#   Neighborhood 223: 560298.34 units
#   Neighborhood 237: 509307.12 units
#   Neighborhood 242: 922827.49 units
#   Neighborhood 244: 737793.87 units
#   Neighborhood 246: 37384.88 units
#   Neighborhood 248: 1.84207706e6 units
#   Neighborhood 250: 2.93777143e6 units
#   Neighborhood 252: 1.57633239e6 units
#   Neighborhood 254: 125717.44 units
#   Neighborhood 255: 2.03696497e6 units
#   Neighborhood 269: 130707.95 units
#   Neighborhood 277: 88214.41 units
#   Neighborhood 313: 1.23241672e6 units
#   Neighborhood 319: 624041.39 units
#   Neighborhood 324: 3.54929376e6 units
#   Neighborhood 325: 129753.36 units
#   Neighborhood 326: 104606.61 units
#   Neighborhood 327: 557994.27 units
#   Neighborhood 352: 2.09272379e6 units
#   Neighborhood 363: 658173.87 units
#   Neighborhood 364: 2.28379949e6 units
#   Neighborhood 367: 1.57475088e6 units
#   Neighborhood 371: 290533.84 units
#   Neighborhood 380: 561049.68 units
#   Neighborhood 384: 722445.96 units
#   Neighborhood 400: 82217.31 units
#   Neighborhood 401: 225650.67 units
#   Neighborhood 402: 904474.36 units
#   Neighborhood 404: 1.17085996e6 units
#   Neighborhood 417: 255191.16 units
#   Neighborhood 434: 77079.76 units
#   Neighborhood 439: 549180.62 units
#   Neighborhood 441: 156023.38 units
#   Neighborhood 445: 674232.77 units
#   Neighborhood 447: 1.40976874e6 units
#   Neighborhood 449: 1.54032922e6 units
#   Neighborhood 452: 1.73749145e6 units
#   Neighborhood 474: 478056.68 units
#   Neighborhood 479: 196019.04 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 516: 180238.28 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 1.00167224e6 units
#   Neighborhood 526: 164804.51 units
#   Neighborhood 527: 1.10132634e6 units
#   Neighborhood 529: 2.2635378e6 units
#   Neighborhood 549: 1.12841043e6 units
#   Neighborhood 560: 522387.67 units
#   Neighborhood 561: 1.54262083e6 units
#   Neighborhood 564: 655645.12 units
#   Neighborhood 581: 709989.79 units
#   Neighborhood 585: 37083.23 units
#
# Total neighborhoods receiving any food: 98
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 1.0, w_eq = 3.0 ===
# Total miles driven (transport cost, no penalty): 8.895466e6
# Worst remaining deficit: 1.13421375e6 units in neighborhood 352
#
# Neighborhoods that received food:
#
#   Neighborhood 1: 102142.62 units
#   Neighborhood 2: 234918.93 units
#   Neighborhood 4: 113652.81 units
#   Neighborhood 20: 23547.32 units
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 1.18393395e6 units
#   Neighborhood 50: 105498.51 units
#   Neighborhood 59: 23285.42 units
#   Neighborhood 69: 1.09718042e6 units
#   Neighborhood 80: 238489.99 units
#   Neighborhood 93: 89959.74 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 129: 1.79769511e6 units
#   Neighborhood 135: 363136.01 units
#   Neighborhood 140: 368038.65 units
#   Neighborhood 141: 929010.72 units
#   Neighborhood 147: 272014.5 units
#   Neighborhood 155: 720808.95 units
#   Neighborhood 156: 2.50267088e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 162: 74667.07 units
#   Neighborhood 163: 105866.87 units
#   Neighborhood 165: 1.03534203e6 units
#   Neighborhood 166: 688797.41 units
#   Neighborhood 168: 964643.18 units
#   Neighborhood 172: 1.19478145e6 units
#   Neighborhood 174: 502559.5 units
#   Neighborhood 179: 230027.66 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 183: 1.42730274e6 units
#   Neighborhood 191: 1.14923347e6 units
#   Neighborhood 195: 1.19582559e6 units
#   Neighborhood 196: 2.30301083e6 units
#   Neighborhood 203: 13128.31 units
#   Neighborhood 207: 2.46610213e6 units
#   Neighborhood 210: 32270.68 units
#   Neighborhood 211: 389409.47 units
#   Neighborhood 221: 404200.91 units
#   Neighborhood 222: 56409.56 units
#   Neighborhood 223: 560298.34 units
#   Neighborhood 242: 1.12899104e6 units
#   Neighborhood 246: 243548.44 units
#   Neighborhood 247: 23157.51 units
#   Neighborhood 248: 2.04824062e6 units
#   Neighborhood 250: 3.14393499e6 units
#   Neighborhood 252: 1.57633239e6 units
#   Neighborhood 254: 331881.0 units
#   Neighborhood 255: 1.25815696e6 units
#   Neighborhood 269: 130707.95 units
#   Neighborhood 277: 88214.41 units
#   Neighborhood 313: 1.23241672e6 units
#   Neighborhood 319: 624041.39 units
#   Neighborhood 324: 3.54929376e6 units
#   Neighborhood 325: 129753.36 units
#   Neighborhood 326: 104606.61 units
#   Neighborhood 327: 557994.27 units
#   Neighborhood 352: 2.29888735e6 units
#   Neighborhood 363: 864337.42 units
#   Neighborhood 364: 2.48996304e6 units
#   Neighborhood 367: 1.78091443e6 units
#   Neighborhood 368: 165227.97 units
#   Neighborhood 371: 496697.4 units
#   Neighborhood 373: 157786.85 units
#   Neighborhood 380: 767213.23 units
#   Neighborhood 384: 250735.93 units
#   Neighborhood 400: 82217.31 units
#   Neighborhood 401: 225650.67 units
#   Neighborhood 402: 904474.36 units
#   Neighborhood 404: 1.17085996e6 units
#   Neighborhood 417: 255191.16 units
#   Neighborhood 439: 755344.18 units
#   Neighborhood 445: 880396.33 units
#   Neighborhood 447: 1.61593229e6 units
#   Neighborhood 449: 1.54032922e6 units
#   Neighborhood 451: 51549.79 units
#   Neighborhood 452: 1.73749145e6 units
#   Neighborhood 474: 405378.23 units
#   Neighborhood 479: 196019.04 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 516: 180238.28 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 1.00167224e6 units
#   Neighborhood 526: 164804.51 units
#   Neighborhood 527: 1.10132634e6 units
#   Neighborhood 529: 1.12932405e6 units
#   Neighborhood 549: 1.33457398e6 units
#   Neighborhood 560: 728551.22 units
#   Neighborhood 561: 1.74878438e6 units
#   Neighborhood 564: 861808.68 units
#   Neighborhood 577: 132465.49 units
#   Neighborhood 585: 37083.23 units
#
# Total neighborhoods receiving any food: 95
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 1.0, w_eq = 4.0 ===
# Total miles driven (transport cost, no penalty): 9.444624e6
# Worst remaining deficit: 974883.05 units in neighborhood 196
#
# Neighborhoods that received food:
#
#   Neighborhood 1: 102142.62 units
#   Neighborhood 2: 208033.49 units
#   Neighborhood 4: 113652.81 units
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 1.18393395e6 units
#   Neighborhood 50: 105498.51 units
#   Neighborhood 56: 4231.64 units
#   Neighborhood 59: 23285.42 units
#   Neighborhood 69: 1.25651113e6 units
#   Neighborhood 93: 89959.74 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 129: 1.95702582e6 units
#   Neighborhood 135: 363136.01 units
#   Neighborhood 140: 527369.36 units
#   Neighborhood 141: 1.08834143e6 units
#   Neighborhood 147: 272014.5 units
#   Neighborhood 155: 306918.76 units
#   Neighborhood 156: 1.52778783e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 162: 233997.77 units
#   Neighborhood 163: 105866.87 units
#   Neighborhood 165: 1.19467274e6 units
#   Neighborhood 166: 848128.12 units
#   Neighborhood 168: 1.12397389e6 units
#   Neighborhood 172: 1.35411215e6 units
#   Neighborhood 174: 256882.43 units
#   Neighborhood 175: 10403.64 units
#   Neighborhood 179: 389358.36 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 183: 1.58663345e6 units
#   Neighborhood 191: 1.30856418e6 units
#   Neighborhood 195: 1.3551563e6 units
#   Neighborhood 196: 2.46234153e6 units
#   Neighborhood 203: 13128.31 units
#   Neighborhood 207: 1.49121908e6 units
#   Neighborhood 210: 191601.39 units
#   Neighborhood 211: 548740.17 units
#   Neighborhood 242: 1.28832175e6 units
#   Neighborhood 245: 72256.94 units
#   Neighborhood 246: 402879.14 units
#   Neighborhood 247: 182488.21 units
#   Neighborhood 248: 2.20757132e6 units
#   Neighborhood 250: 3.30326569e6 units
#   Neighborhood 252: 1.57633239e6 units
#   Neighborhood 254: 491211.7 units
#   Neighborhood 255: 1.06208192e6 units
#   Neighborhood 269: 130707.95 units
#   Neighborhood 277: 88214.41 units
#   Neighborhood 313: 1.23241672e6 units
#   Neighborhood 319: 624041.39 units
#   Neighborhood 324: 3.54929376e6 units
#   Neighborhood 325: 129753.36 units
#   Neighborhood 326: 104606.61 units
#   Neighborhood 327: 557994.27 units
#   Neighborhood 352: 2.45821805e6 units
#   Neighborhood 363: 1.02366813e6 units
#   Neighborhood 364: 2.64929375e6 units
#   Neighborhood 366: 159330.71 units
#   Neighborhood 367: 1.94024514e6 units
#   Neighborhood 368: 324558.68 units
#   Neighborhood 371: 656028.1 units
#   Neighborhood 373: 317117.56 units
#   Neighborhood 380: 926543.94 units
#   Neighborhood 384: 664626.12 units
#   Neighborhood 400: 82217.31 units
#   Neighborhood 401: 225650.67 units
#   Neighborhood 402: 904474.36 units
#   Neighborhood 404: 195976.91 units
#   Neighborhood 417: 255191.16 units
#   Neighborhood 439: 914674.88 units
#   Neighborhood 445: 1.03972703e6 units
#   Neighborhood 447: 1.775263e6 units
#   Neighborhood 449: 1.54032922e6 units
#   Neighborhood 451: 210880.5 units
#   Neighborhood 452: 762608.4 units
#   Neighborhood 474: 405378.23 units
#   Neighborhood 479: 196019.04 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 516: 180238.28 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 1.00167224e6 units
#   Neighborhood 526: 164804.51 units
#   Neighborhood 527: 126443.3 units
#   Neighborhood 529: 1.28865475e6 units
#   Neighborhood 549: 1.49390469e6 units
#   Neighborhood 560: 887881.93 units
#   Neighborhood 561: 1.90811509e6 units
#   Neighborhood 564: 1.02113938e6 units
#   Neighborhood 568: 6547.77 units
#   Neighborhood 577: 291796.2 units
#   Neighborhood 585: 37083.23 units
#
# Total neighborhoods receiving any food: 95
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 1.0, w_eq = 5.0 ===
# Total miles driven (transport cost, no penalty): 9.742846e6
# Worst remaining deficit: 910017.37 units in neighborhood 69
#
# Neighborhoods that received food:
#
#   Neighborhood 1: 102142.62 units
#   Neighborhood 4: 113652.81 units
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 716416.71 units
#   Neighborhood 50: 105498.51 units
#   Neighborhood 56: 69097.32 units
#   Neighborhood 69: 1.3213768e6 units
#   Neighborhood 93: 89959.74 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 129: 2.02189149e6 units
#   Neighborhood 135: 363136.01 units
#   Neighborhood 140: 592235.03 units
#   Neighborhood 141: 1.1532071e6 units
#   Neighborhood 147: 272014.5 units
#   Neighborhood 156: 1.5926535e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 162: 298863.45 units
#   Neighborhood 163: 105866.87 units
#   Neighborhood 165: 1.25953841e6 units
#   Neighborhood 166: 912993.79 units
#   Neighborhood 168: 1.18883956e6 units
#   Neighborhood 172: 1.41897782e6 units
#   Neighborhood 174: 256882.43 units
#   Neighborhood 175: 75269.31 units
#   Neighborhood 179: 454224.04 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 183: 1.65149912e6 units
#   Neighborhood 191: 1.37342985e6 units
#   Neighborhood 195: 1.42002197e6 units
#   Neighborhood 196: 2.52720721e6 units
#   Neighborhood 203: 13128.31 units
#   Neighborhood 207: 1.55608475e6 units
#   Neighborhood 210: 256467.06 units
#   Neighborhood 211: 613605.85 units
#   Neighborhood 242: 1.35318742e6 units
#   Neighborhood 245: 137122.61 units
#   Neighborhood 246: 467744.82 units
#   Neighborhood 247: 247353.89 units
#   Neighborhood 248: 2.272437e6 units
#   Neighborhood 250: 3.36813137e6 units
#   Neighborhood 252: 666315.01 units
#   Neighborhood 254: 556077.38 units
#   Neighborhood 255: 1.1269476e6 units
#   Neighborhood 269: 130707.95 units
#   Neighborhood 277: 88214.41 units
#   Neighborhood 313: 1.23241672e6 units
#   Neighborhood 319: 624041.39 units
#   Neighborhood 324: 3.54929376e6 units
#   Neighborhood 325: 129753.36 units
#   Neighborhood 326: 104606.61 units
#   Neighborhood 327: 557994.27 units
#   Neighborhood 352: 2.52308373e6 units
#   Neighborhood 363: 1.0885338e6 units
#   Neighborhood 364: 2.71415942e6 units
#   Neighborhood 365: 15178.05 units
#   Neighborhood 366: 224196.38 units
#   Neighborhood 367: 2.00511081e6 units
#   Neighborhood 368: 389424.35 units
#   Neighborhood 371: 720893.78 units
#   Neighborhood 373: 381983.23 units
#   Neighborhood 380: 991409.61 units
#   Neighborhood 384: 148942.39 units
#   Neighborhood 400: 82217.31 units
#   Neighborhood 401: 225650.67 units
#   Neighborhood 402: 904474.36 units
#   Neighborhood 404: 260842.59 units
#   Neighborhood 417: 255191.16 units
#   Neighborhood 439: 979540.56 units
#   Neighborhood 445: 1.10459271e6 units
#   Neighborhood 447: 1.84012867e6 units
#   Neighborhood 449: 813262.3 units
#   Neighborhood 451: 275746.17 units
#   Neighborhood 452: 827474.07 units
#   Neighborhood 474: 405378.23 units
#   Neighborhood 479: 196019.04 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 516: 180238.28 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 1.00167224e6 units
#   Neighborhood 527: 191308.97 units
#   Neighborhood 529: 1.35352042e6 units
#   Neighborhood 549: 1.55877036e6 units
#   Neighborhood 560: 952747.6 units
#   Neighborhood 561: 1.97298076e6 units
#   Neighborhood 564: 1.08600505e6 units
#   Neighborhood 568: 71413.44 units
#   Neighborhood 577: 356661.87 units
#   Neighborhood 585: 37083.23 units
#
# Total neighborhoods receiving any food: 92
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 1.0, w_eq = 6.0 ===
# Total miles driven (transport cost, no penalty): 1.0081772e7
# Worst remaining deficit: 847789.09 units in neighborhood 33
#
# Neighborhoods that received food:
#
#   Neighborhood 4: 30374.2 units
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 336144.86 units
#   Neighborhood 50: 105498.51 units
#   Neighborhood 56: 131325.6 units
#   Neighborhood 69: 1.38360509e6 units
#   Neighborhood 93: 89959.74 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 129: 2.08411978e6 units
#   Neighborhood 140: 654463.32 units
#   Neighborhood 141: 1.21543539e6 units
#   Neighborhood 147: 272014.5 units
#   Neighborhood 156: 1.65488179e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 162: 361091.73 units
#   Neighborhood 163: 105866.87 units
#   Neighborhood 165: 1.3217667e6 units
#   Neighborhood 166: 975222.08 units
#   Neighborhood 168: 1.25106785e6 units
#   Neighborhood 172: 1.48120611e6 units
#   Neighborhood 174: 4495.47 units
#   Neighborhood 175: 137497.6 units
#   Neighborhood 179: 516452.32 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 183: 1.71372741e6 units
#   Neighborhood 191: 1.43565814e6 units
#   Neighborhood 195: 1.48225026e6 units
#   Neighborhood 196: 2.58943549e6 units
#   Neighborhood 203: 13128.31 units
#   Neighborhood 207: 1.61831304e6 units
#   Neighborhood 210: 318695.35 units
#   Neighborhood 211: 675834.13 units
#   Neighborhood 214: 31046.34 units
#   Neighborhood 242: 1.41541571e6 units
#   Neighborhood 245: 199350.9 units
#   Neighborhood 246: 529973.1 units
#   Neighborhood 247: 309582.17 units
#   Neighborhood 248: 2.33466528e6 units
#   Neighborhood 250: 3.43035965e6 units
#   Neighborhood 252: 728543.3 units
#   Neighborhood 254: 618305.66 units
#   Neighborhood 255: 1.18917588e6 units
#   Neighborhood 269: 130707.95 units
#   Neighborhood 313: 1.23241672e6 units
#   Neighborhood 319: 624041.39 units
#   Neighborhood 324: 3.54929376e6 units
#   Neighborhood 325: 129753.36 units
#   Neighborhood 326: 104606.61 units
#   Neighborhood 352: 2.58531201e6 units
#   Neighborhood 363: 1.15076209e6 units
#   Neighborhood 364: 2.77638771e6 units
#   Neighborhood 365: 77406.34 units
#   Neighborhood 366: 286424.67 units
#   Neighborhood 367: 2.0673391e6 units
#   Neighborhood 368: 451652.64 units
#   Neighborhood 371: 783122.06 units
#   Neighborhood 373: 444211.52 units
#   Neighborhood 380: 1.0536379e6 units
#   Neighborhood 400: 82217.31 units
#   Neighborhood 401: 225650.67 units
#   Neighborhood 402: 56685.28 units
#   Neighborhood 404: 323070.87 units
#   Neighborhood 439: 1.04176884e6 units
#   Neighborhood 445: 1.16682099e6 units
#   Neighborhood 447: 1.90235696e6 units
#   Neighborhood 449: 692540.13 units
#   Neighborhood 450: 35146.39 units
#   Neighborhood 451: 337974.46 units
#   Neighborhood 452: 889702.36 units
#   Neighborhood 474: 241155.88 units
#   Neighborhood 479: 196019.04 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 516: 180238.28 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 1.00167224e6 units
#   Neighborhood 527: 253537.26 units
#   Neighborhood 529: 1.41574871e6 units
#   Neighborhood 549: 1.62099865e6 units
#   Neighborhood 560: 1.01497589e6 units
#   Neighborhood 561: 2.03520905e6 units
#   Neighborhood 564: 1.14823334e6 units
#   Neighborhood 568: 133641.73 units
#   Neighborhood 577: 418890.16 units
#   Neighborhood 585: 37083.23 units
#
# Total neighborhoods receiving any food: 88
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 1.0, w_eq = 7.0 ===
# Total miles driven (transport cost, no penalty): 1.0328564e7
# Worst remaining deficit: 810974.15 units in neighborhood 255
#
# Neighborhoods that received food:
#
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 372959.8 units
#   Neighborhood 56: 168140.54 units
#   Neighborhood 69: 1.42042003e6 units
#   Neighborhood 93: 89959.74 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 129: 2.12093471e6 units
#   Neighborhood 140: 691278.26 units
#   Neighborhood 141: 1.25225033e6 units
#   Neighborhood 156: 1.69169673e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 162: 397906.67 units
#   Neighborhood 163: 105866.87 units
#   Neighborhood 165: 1.35858164e6 units
#   Neighborhood 166: 1.01203702e6 units
#   Neighborhood 168: 1.28788279e6 units
#   Neighborhood 172: 1.51802105e6 units
#   Neighborhood 174: 41310.41 units
#   Neighborhood 175: 174312.54 units
#   Neighborhood 179: 553267.26 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 183: 1.75054234e6 units
#   Neighborhood 191: 1.47247307e6 units
#   Neighborhood 195: 1.5190652e6 units
#   Neighborhood 196: 2.62625043e6 units
#   Neighborhood 203: 13128.31 units
#   Neighborhood 207: 1.65512798e6 units
#   Neighborhood 210: 355510.29 units
#   Neighborhood 211: 712649.07 units
#   Neighborhood 214: 67861.28 units
#   Neighborhood 242: 1.45223065e6 units
#   Neighborhood 245: 236165.84 units
#   Neighborhood 246: 566788.04 units
#   Neighborhood 247: 346397.11 units
#   Neighborhood 248: 2.37148022e6 units
#   Neighborhood 250: 3.46717459e6 units
#   Neighborhood 252: 765358.24 units
#   Neighborhood 254: 655120.6 units
#   Neighborhood 255: 1.22599082e6 units
#   Neighborhood 277: 88214.41 units
#   Neighborhood 313: 1.23241672e6 units
#   Neighborhood 319: 90542.77 units
#   Neighborhood 324: 3.54929376e6 units
#   Neighborhood 325: 129753.36 units
#   Neighborhood 352: 2.62212695e6 units
#   Neighborhood 363: 1.18757703e6 units
#   Neighborhood 364: 2.81320265e6 units
#   Neighborhood 365: 114221.28 units
#   Neighborhood 366: 323239.6 units
#   Neighborhood 367: 2.10415404e6 units
#   Neighborhood 368: 488467.58 units
#   Neighborhood 371: 819937.0 units
#   Neighborhood 372: 35896.49 units
#   Neighborhood 373: 481026.45 units
#   Neighborhood 380: 1.09045284e6 units
#   Neighborhood 400: 82217.31 units
#   Neighborhood 402: 93500.21 units
#   Neighborhood 404: 359885.81 units
#   Neighborhood 407: 5347.32 units
#   Neighborhood 439: 1.07858378e6 units
#   Neighborhood 445: 1.20363593e6 units
#   Neighborhood 447: 1.9391719e6 units
#   Neighborhood 449: 729355.07 units
#   Neighborhood 450: 71961.33 units
#   Neighborhood 451: 374789.4 units
#   Neighborhood 452: 926517.3 units
#   Neighborhood 474: 152941.46 units
#   Neighborhood 479: 196019.04 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 516: 180238.28 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 190698.09 units
#   Neighborhood 527: 290352.2 units
#   Neighborhood 529: 1.45256365e6 units
#   Neighborhood 549: 1.65781359e6 units
#   Neighborhood 560: 1.05179083e6 units
#   Neighborhood 561: 2.07202399e6 units
#   Neighborhood 564: 1.18504828e6 units
#   Neighborhood 568: 170456.67 units
#   Neighborhood 577: 455705.1 units
#   Neighborhood 585: 37083.23 units
#
# Total neighborhoods receiving any food: 85
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 1.0, w_eq = 8.0 ===
# Total miles driven (transport cost, no penalty): 1.043224e7
# Worst remaining deficit: 797194.91 units in neighborhood 33
#
# Neighborhoods that received food:
#
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 386739.04 units
#   Neighborhood 56: 181919.78 units
#   Neighborhood 69: 1.43419927e6 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 129: 2.13471396e6 units
#   Neighborhood 140: 705057.5 units
#   Neighborhood 141: 1.26602957e6 units
#   Neighborhood 156: 1.70547597e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 162: 411685.91 units
#   Neighborhood 163: 18365.92 units
#   Neighborhood 165: 1.37236088e6 units
#   Neighborhood 166: 1.02581626e6 units
#   Neighborhood 168: 1.30166203e6 units
#   Neighborhood 172: 1.53180029e6 units
#   Neighborhood 174: 55089.65 units
#   Neighborhood 175: 188091.78 units
#   Neighborhood 179: 567046.5 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 183: 1.76432159e6 units
#   Neighborhood 191: 1.48625232e6 units
#   Neighborhood 195: 1.53284444e6 units
#   Neighborhood 196: 2.64002967e6 units
#   Neighborhood 207: 1.66890722e6 units
#   Neighborhood 210: 369289.53 units
#   Neighborhood 211: 726428.31 units
#   Neighborhood 214: 81640.52 units
#   Neighborhood 242: 1.46600989e6 units
#   Neighborhood 245: 249945.08 units
#   Neighborhood 246: 580567.28 units
#   Neighborhood 247: 360176.35 units
#   Neighborhood 248: 2.38525946e6 units
#   Neighborhood 250: 3.48095383e6 units
#   Neighborhood 252: 779137.48 units
#   Neighborhood 254: 668899.84 units
#   Neighborhood 255: 1.23977006e6 units
#   Neighborhood 313: 1.23241672e6 units
#   Neighborhood 324: 3.54929376e6 units
#   Neighborhood 325: 129753.36 units
#   Neighborhood 352: 2.63590619e6 units
#   Neighborhood 363: 1.20135627e6 units
#   Neighborhood 364: 2.82698189e6 units
#   Neighborhood 365: 128000.52 units
#   Neighborhood 366: 337018.85 units
#   Neighborhood 367: 2.11793328e6 units
#   Neighborhood 368: 502246.82 units
#   Neighborhood 371: 833716.24 units
#   Neighborhood 372: 49675.73 units
#   Neighborhood 373: 494805.7 units
#   Neighborhood 380: 1.10423208e6 units
#   Neighborhood 402: 107279.46 units
#   Neighborhood 404: 373665.05 units
#   Neighborhood 407: 19126.56 units
#   Neighborhood 439: 1.09236302e6 units
#   Neighborhood 442: 13342.61 units
#   Neighborhood 445: 1.21741517e6 units
#   Neighborhood 447: 1.95295114e6 units
#   Neighborhood 449: 743134.31 units
#   Neighborhood 450: 85740.57 units
#   Neighborhood 451: 388568.64 units
#   Neighborhood 452: 940296.54 units
#   Neighborhood 479: 60921.4 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 516: 89268.61 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 204477.33 units
#   Neighborhood 527: 304131.44 units
#   Neighborhood 529: 1.46634289e6 units
#   Neighborhood 549: 1.67159283e6 units
#   Neighborhood 560: 1.06557007e6 units
#   Neighborhood 561: 2.08580323e6 units
#   Neighborhood 564: 1.19882752e6 units
#   Neighborhood 568: 184235.91 units
#   Neighborhood 577: 469484.34 units
#
# Total neighborhoods receiving any food: 79
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 1.0, w_eq = 9.0 ===
# Total miles driven (transport cost, no penalty): 1.045395e7
# Worst remaining deficit: 794577.23 units in neighborhood 129
#
# Neighborhoods that received food:
#
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 389356.72 units
#   Neighborhood 56: 184537.46 units
#   Neighborhood 69: 1.43681695e6 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 129: 2.13733164e6 units
#   Neighborhood 140: 707675.18 units
#   Neighborhood 141: 1.26864725e6 units
#   Neighborhood 149: 1024.37 units
#   Neighborhood 156: 1.70809365e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 162: 414303.59 units
#   Neighborhood 165: 1.37497856e6 units
#   Neighborhood 166: 1.02843394e6 units
#   Neighborhood 168: 1.30427971e6 units
#   Neighborhood 172: 1.53441797e6 units
#   Neighborhood 174: 57707.33 units
#   Neighborhood 175: 190709.46 units
#   Neighborhood 179: 569664.18 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 183: 1.76693927e6 units
#   Neighborhood 191: 1.48887e6 units
#   Neighborhood 195: 1.53546212e6 units
#   Neighborhood 196: 2.64264735e6 units
#   Neighborhood 197: 2617.68 units
#   Neighborhood 207: 1.6715249e6 units
#   Neighborhood 210: 371907.21 units
#   Neighborhood 211: 729045.99 units
#   Neighborhood 214: 84258.2 units
#   Neighborhood 242: 1.46862757e6 units
#   Neighborhood 245: 252562.76 units
#   Neighborhood 246: 583184.96 units
#   Neighborhood 247: 362794.03 units
#   Neighborhood 248: 2.38787714e6 units
#   Neighborhood 250: 3.48357151e6 units
#   Neighborhood 252: 781755.16 units
#   Neighborhood 254: 671517.52 units
#   Neighborhood 255: 1.24238774e6 units
#   Neighborhood 313: 1.23241672e6 units
#   Neighborhood 324: 3.54929376e6 units
#   Neighborhood 325: 129753.36 units
#   Neighborhood 352: 2.63852387e6 units
#   Neighborhood 363: 1.20397395e6 units
#   Neighborhood 364: 2.82959957e6 units
#   Neighborhood 365: 130618.2 units
#   Neighborhood 366: 339636.53 units
#   Neighborhood 367: 2.12055096e6 units
#   Neighborhood 368: 504864.5 units
#   Neighborhood 371: 836333.92 units
#   Neighborhood 372: 52293.41 units
#   Neighborhood 373: 497423.38 units
#   Neighborhood 380: 1.10684976e6 units
#   Neighborhood 402: 109897.14 units
#   Neighborhood 404: 376282.73 units
#   Neighborhood 407: 21744.24 units
#   Neighborhood 439: 1.0949807e6 units
#   Neighborhood 442: 15960.29 units
#   Neighborhood 445: 1.22003285e6 units
#   Neighborhood 447: 1.95556882e6 units
#   Neighborhood 449: 745751.99 units
#   Neighborhood 450: 88358.25 units
#   Neighborhood 451: 391186.32 units
#   Neighborhood 452: 942914.22 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 207095.01 units
#   Neighborhood 527: 306749.12 units
#   Neighborhood 529: 1.46896057e6 units
#   Neighborhood 549: 1.67421051e6 units
#   Neighborhood 560: 1.06818775e6 units
#   Neighborhood 561: 2.08842091e6 units
#   Neighborhood 564: 1.2014452e6 units
#   Neighborhood 568: 186853.59 units
#   Neighborhood 577: 472102.02 units
#
# Total neighborhoods receiving any food: 78
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 1.0, w_eq = 10.0 ===
# Total miles driven (transport cost, no penalty): 1.1048218e7
# Worst remaining deficit: 731641.08 units in neighborhood 129
#
# Neighborhoods that received food:
#
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 452292.86 units
#   Neighborhood 56: 247473.61 units
#   Neighborhood 69: 1.49975309e6 units
#   Neighborhood 129: 2.20026778e6 units
#   Neighborhood 140: 770611.32 units
#   Neighborhood 141: 1.33158339e6 units
#   Neighborhood 149: 63960.51 units
#   Neighborhood 156: 1.7710298e6 units
#   Neighborhood 162: 477239.74 units
#   Neighborhood 165: 1.4379147e6 units
#   Neighborhood 166: 1.09137008e6 units
#   Neighborhood 168: 1.36721585e6 units
#   Neighborhood 172: 1.59735412e6 units
#   Neighborhood 174: 120643.48 units
#   Neighborhood 175: 253645.6 units
#   Neighborhood 179: 632600.33 units
#   Neighborhood 182: 2.54108399e6 units
#   Neighborhood 183: 1.82987541e6 units
#   Neighborhood 191: 1.55180614e6 units
#   Neighborhood 195: 1.59839826e6 units
#   Neighborhood 196: 2.7055835e6 units
#   Neighborhood 197: 65553.83 units
#   Neighborhood 207: 1.73446105e6 units
#   Neighborhood 210: 434843.35 units
#   Neighborhood 211: 791982.14 units
#   Neighborhood 214: 147194.35 units
#   Neighborhood 242: 1.53156371e6 units
#   Neighborhood 244: 6152.79 units
#   Neighborhood 245: 315498.9 units
#   Neighborhood 246: 646121.11 units
#   Neighborhood 247: 425730.18 units
#   Neighborhood 248: 2.45081329e6 units
#   Neighborhood 250: 3.54650766e6 units
#   Neighborhood 252: 844691.3 units
#   Neighborhood 254: 734453.67 units
#   Neighborhood 255: 1.30532389e6 units
#   Neighborhood 313: 521045.1 units
#   Neighborhood 324: 2.81765268e6 units
#   Neighborhood 352: 2.70146002e6 units
#   Neighborhood 363: 1.26691009e6 units
#   Neighborhood 364: 2.89253571e6 units
#   Neighborhood 365: 193554.35 units
#   Neighborhood 366: 402572.67 units
#   Neighborhood 367: 2.1834871e6 units
#   Neighborhood 368: 567800.64 units
#   Neighborhood 371: 899270.07 units
#   Neighborhood 372: 115229.55 units
#   Neighborhood 373: 560359.52 units
#   Neighborhood 380: 1.1697859e6 units
#   Neighborhood 402: 172833.28 units
#   Neighborhood 404: 439218.88 units
#   Neighborhood 407: 84680.39 units
#   Neighborhood 439: 1.15791685e6 units
#   Neighborhood 442: 78896.44 units
#   Neighborhood 445: 1.282969e6 units
#   Neighborhood 447: 2.01850496e6 units
#   Neighborhood 449: 808688.14 units
#   Neighborhood 450: 151294.4 units
#   Neighborhood 451: 454122.47 units
#   Neighborhood 452: 1.00585036e6 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 92298.87 units
#   Neighborhood 521: 661040.71 units
#   Neighborhood 523: 270031.16 units
#   Neighborhood 527: 369685.26 units
#   Neighborhood 529: 1.53189672e6 units
#   Neighborhood 549: 1.73714665e6 units
#   Neighborhood 560: 1.1311239e6 units
#   Neighborhood 561: 2.15135705e6 units
#   Neighborhood 564: 1.26438135e6 units
#   Neighborhood 568: 249789.74 units
#   Neighborhood 577: 535038.16 units
#
# Total neighborhoods receiving any food: 75
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 10.0, w_eq = 1.0 ===
# Total miles driven (transport cost, no penalty): 6.934084e6
# Worst remaining deficit: 2.91512819e6 units in neighborhood 129
#
# Neighborhoods that received food:
#
#   Neighborhood 1: 102142.62 units
#   Neighborhood 2: 333492.65 units
#   Neighborhood 4: 113652.81 units
#   Neighborhood 8: 113911.46 units
#   Neighborhood 20: 23547.32 units
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 1.18393395e6 units
#   Neighborhood 40: 40369.71 units
#   Neighborhood 50: 105498.51 units
#   Neighborhood 56: 979114.69 units
#   Neighborhood 59: 23285.42 units
#   Neighborhood 80: 238489.99 units
#   Neighborhood 93: 89959.74 units
#   Neighborhood 101: 704873.88 units
#   Neighborhood 111: 258687.53 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 115: 175960.45 units
#   Neighborhood 118: 261754.51 units
#   Neighborhood 120: 405519.22 units
#   Neighborhood 124: 2162.6 units
#   Neighborhood 129: 16780.68 units
#   Neighborhood 135: 363136.01 units
#   Neighborhood 140: 141381.06 units
#   Neighborhood 147: 272014.5 units
#   Neighborhood 155: 720808.95 units
#   Neighborhood 156: 2.50267088e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 163: 105866.87 units
#   Neighborhood 166: 177171.69 units
#   Neighborhood 168: 2.09885694e6 units
#   Neighborhood 172: 754852.26 units
#   Neighborhood 173: 25318.04 units
#   Neighborhood 174: 304986.03 units
#   Neighborhood 175: 985286.69 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 191: 2.28344722e6 units
#   Neighborhood 194: 311007.77 units
#   Neighborhood 195: 246155.18 units
#   Neighborhood 196: 522096.39 units
#   Neighborhood 197: 797194.91 units
#   Neighborhood 203: 13128.31 units
#   Neighborhood 207: 2.46610213e6 units
#   Neighborhood 209: 373365.51 units
#   Neighborhood 214: 123843.42 units
#   Neighborhood 221: 404200.91 units
#   Neighborhood 222: 56409.56 units
#   Neighborhood 223: 560298.34 units
#   Neighborhood 233: 474243.0 units
#   Neighborhood 236: 424811.03 units
#   Neighborhood 237: 509307.12 units
#   Neighborhood 242: 2.2632048e6 units
#   Neighborhood 244: 737793.87 units
#   Neighborhood 245: 1.04713999e6 units
#   Neighborhood 246: 1.37776219e6 units
#   Neighborhood 247: 1.15737126e6 units
#   Neighborhood 248: 267326.19 units
#   Neighborhood 250: 1.36302055e6 units
#   Neighborhood 252: 1.57633239e6 units
#   Neighborhood 253: 690257.6 units
#   Neighborhood 254: 1.46609475e6 units
#   Neighborhood 255: 2.03696497e6 units
#   Neighborhood 269: 130707.95 units
#   Neighborhood 277: 88214.41 units
#   Neighborhood 313: 1.23241672e6 units
#   Neighborhood 319: 624041.39 units
#   Neighborhood 324: 3.54929376e6 units
#   Neighborhood 325: 129753.36 units
#   Neighborhood 326: 104606.61 units
#   Neighborhood 327: 557994.27 units
#   Neighborhood 336: 481957.93 units
#   Neighborhood 346: 311932.67 units
#   Neighborhood 352: 517972.91 units
#   Neighborhood 355: 196114.86 units
#   Neighborhood 364: 709048.61 units
#   Neighborhood 371: 317865.15 units
#   Neighborhood 379: 237746.9 units
#   Neighborhood 380: 1.90142699e6 units
#   Neighborhood 381: 124780.28 units
#   Neighborhood 384: 722445.96 units
#   Neighborhood 400: 82217.31 units
#   Neighborhood 401: 225650.67 units
#   Neighborhood 402: 904474.36 units
#   Neighborhood 404: 1.17085996e6 units
#   Neighborhood 417: 255191.16 units
#   Neighborhood 434: 77079.76 units
#   Neighborhood 439: 1.88955793e6 units
#   Neighborhood 441: 156023.38 units
#   Neighborhood 442: 810537.52 units
#   Neighborhood 443: 575068.83 units
#   Neighborhood 444: 319917.59 units
#   Neighborhood 449: 1.54032922e6 units
#   Neighborhood 450: 882935.48 units
#   Neighborhood 451: 1.18576355e6 units
#   Neighborhood 452: 1.73749145e6 units
#   Neighborhood 474: 478056.68 units
#   Neighborhood 479: 196019.04 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 516: 180238.28 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 1.00167224e6 units
#   Neighborhood 526: 164804.51 units
#   Neighborhood 527: 1.10132634e6 units
#   Neighborhood 529: 2.2635378e6 units
#   Neighborhood 532: 209126.85 units
#   Neighborhood 533: 527148.97 units
#   Neighborhood 543: 309269.1 units
#   Neighborhood 552: 121379.77 units
#   Neighborhood 577: 876825.15 units
#   Neighborhood 581: 252089.29 units
#   Neighborhood 585: 37083.23 units
#
# Total neighborhoods receiving any food: 114
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 9.0, w_eq = 1.0 ===
# Total miles driven (transport cost, no penalty): 6.935772e6
# Worst remaining deficit: 2.89864768e6 units in neighborhood 129
#
# Neighborhoods that received food:
#
#   Neighborhood 1: 102142.62 units
#   Neighborhood 2: 333492.65 units
#   Neighborhood 4: 113652.81 units
#   Neighborhood 8: 113911.46 units
#   Neighborhood 20: 23547.32 units
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 1.18393395e6 units
#   Neighborhood 40: 40369.71 units
#   Neighborhood 50: 105498.51 units
#   Neighborhood 56: 979114.69 units
#   Neighborhood 59: 23285.42 units
#   Neighborhood 69: 123843.42 units
#   Neighborhood 80: 238489.99 units
#   Neighborhood 93: 89959.74 units
#   Neighborhood 101: 704873.88 units
#   Neighborhood 111: 258687.53 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 115: 175960.45 units
#   Neighborhood 118: 261754.51 units
#   Neighborhood 120: 405519.22 units
#   Neighborhood 124: 2162.6 units
#   Neighborhood 129: 33261.18 units
#   Neighborhood 135: 363136.01 units
#   Neighborhood 147: 272014.5 units
#   Neighborhood 155: 262908.45 units
#   Neighborhood 156: 2.50267088e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 163: 105866.87 units
#   Neighborhood 166: 979333.9 units
#   Neighborhood 168: 2.09885694e6 units
#   Neighborhood 172: 662504.44 units
#   Neighborhood 174: 367092.66 units
#   Neighborhood 175: 985286.69 units
#   Neighborhood 179: 268423.63 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 191: 2.28344722e6 units
#   Neighborhood 194: 311007.77 units
#   Neighborhood 195: 229674.67 units
#   Neighborhood 196: 538576.9 units
#   Neighborhood 197: 797194.91 units
#   Neighborhood 203: 13128.31 units
#   Neighborhood 207: 2.46610213e6 units
#   Neighborhood 209: 373365.51 units
#   Neighborhood 221: 404200.91 units
#   Neighborhood 222: 56409.56 units
#   Neighborhood 223: 560298.34 units
#   Neighborhood 236: 424811.03 units
#   Neighborhood 237: 509307.12 units
#   Neighborhood 242: 2.2632048e6 units
#   Neighborhood 244: 737793.87 units
#   Neighborhood 245: 1.04713999e6 units
#   Neighborhood 246: 1.37776219e6 units
#   Neighborhood 247: 1.15737126e6 units
#   Neighborhood 248: 283806.69 units
#   Neighborhood 250: 1.37950106e6 units
#   Neighborhood 252: 1.57633239e6 units
#   Neighborhood 253: 690257.6 units
#   Neighborhood 254: 1.46609475e6 units
#   Neighborhood 255: 2.03696497e6 units
#   Neighborhood 269: 130707.95 units
#   Neighborhood 277: 88214.41 units
#   Neighborhood 313: 1.23241672e6 units
#   Neighborhood 319: 624041.39 units
#   Neighborhood 324: 3.54929376e6 units
#   Neighborhood 325: 129753.36 units
#   Neighborhood 326: 104606.61 units
#   Neighborhood 327: 557994.27 units
#   Neighborhood 336: 481957.93 units
#   Neighborhood 346: 311932.67 units
#   Neighborhood 352: 610320.74 units
#   Neighborhood 355: 196114.86 units
#   Neighborhood 364: 725529.12 units
#   Neighborhood 367: 16480.51 units
#   Neighborhood 379: 237746.9 units
#   Neighborhood 380: 1.90142699e6 units
#   Neighborhood 381: 124780.28 units
#   Neighborhood 384: 722445.96 units
#   Neighborhood 400: 82217.31 units
#   Neighborhood 401: 225650.67 units
#   Neighborhood 402: 904474.36 units
#   Neighborhood 404: 1.17085996e6 units
#   Neighborhood 407: 108420.05 units
#   Neighborhood 417: 255191.16 units
#   Neighborhood 430: 412136.38 units
#   Neighborhood 434: 77079.76 units
#   Neighborhood 439: 1.88955793e6 units
#   Neighborhood 441: 156023.38 units
#   Neighborhood 442: 810537.52 units
#   Neighborhood 443: 575068.83 units
#   Neighborhood 444: 319917.59 units
#   Neighborhood 449: 1.54032922e6 units
#   Neighborhood 450: 882935.48 units
#   Neighborhood 451: 1.18576355e6 units
#   Neighborhood 452: 1.73749145e6 units
#   Neighborhood 474: 478056.68 units
#   Neighborhood 479: 196019.04 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 516: 180238.28 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 1.00167224e6 units
#   Neighborhood 526: 164804.51 units
#   Neighborhood 527: 1.10132634e6 units
#   Neighborhood 529: 2.2635378e6 units
#   Neighborhood 532: 209126.85 units
#   Neighborhood 533: 527148.97 units
#   Neighborhood 543: 309269.1 units
#   Neighborhood 551: 25318.04 units
#   Neighborhood 552: 121379.77 units
#   Neighborhood 577: 74662.94 units
#   Neighborhood 581: 709989.79 units
#   Neighborhood 585: 37083.23 units
#
# Total neighborhoods receiving any food: 115
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 8.0, w_eq = 1.0 ===
# Total miles driven (transport cost, no penalty): 6.93577e6
# Worst remaining deficit: 2.89864768e6 units in neighborhood 129
#
# Neighborhoods that received food:
#
#   Neighborhood 1: 102142.62 units
#   Neighborhood 2: 333492.65 units
#   Neighborhood 4: 113652.81 units
#   Neighborhood 8: 113911.46 units
#   Neighborhood 20: 23547.32 units
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 1.18393395e6 units
#   Neighborhood 40: 40369.71 units
#   Neighborhood 50: 105498.51 units
#   Neighborhood 56: 979114.69 units
#   Neighborhood 59: 23285.42 units
#   Neighborhood 69: 123843.42 units
#   Neighborhood 80: 238489.99 units
#   Neighborhood 93: 89959.74 units
#   Neighborhood 101: 704873.88 units
#   Neighborhood 111: 258687.53 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 115: 175960.45 units
#   Neighborhood 118: 261754.51 units
#   Neighborhood 120: 405519.22 units
#   Neighborhood 124: 2162.6 units
#   Neighborhood 129: 33261.18 units
#   Neighborhood 135: 363136.01 units
#   Neighborhood 147: 272014.5 units
#   Neighborhood 155: 720808.95 units
#   Neighborhood 156: 2.50267088e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 163: 105866.87 units
#   Neighborhood 168: 2.09885694e6 units
#   Neighborhood 172: 738371.75 units
#   Neighborhood 174: 304986.03 units
#   Neighborhood 175: 985286.69 units
#   Neighborhood 179: 268423.63 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 191: 2.28344722e6 units
#   Neighborhood 194: 311007.77 units
#   Neighborhood 196: 538576.9 units
#   Neighborhood 197: 797194.91 units
#   Neighborhood 203: 13128.31 units
#   Neighborhood 207: 2.46610213e6 units
#   Neighborhood 209: 373365.51 units
#   Neighborhood 221: 404200.91 units
#   Neighborhood 222: 56409.56 units
#   Neighborhood 223: 560298.34 units
#   Neighborhood 233: 474243.0 units
#   Neighborhood 236: 424811.03 units
#   Neighborhood 237: 509307.12 units
#   Neighborhood 242: 2.2632048e6 units
#   Neighborhood 244: 737793.87 units
#   Neighborhood 245: 1.04713999e6 units
#   Neighborhood 246: 1.37776219e6 units
#   Neighborhood 247: 1.15737126e6 units
#   Neighborhood 248: 513481.37 units
#   Neighborhood 250: 1.37950106e6 units
#   Neighborhood 252: 1.57633239e6 units
#   Neighborhood 253: 690257.6 units
#   Neighborhood 254: 1.46609475e6 units
#   Neighborhood 255: 2.03696497e6 units
#   Neighborhood 269: 130707.95 units
#   Neighborhood 277: 88214.41 units
#   Neighborhood 313: 1.23241672e6 units
# ...
#   Neighborhood 450: 882935.48 units
#   Neighborhood 451: 1.18576355e6 units
#   Neighborhood 452: 1.73749145e6 units
#   Neighborhood 474: 656230.84 units
#   Neighborhood 479: 196019.04 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 516: 180238.28 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 1.00167224e6 units
#   Neighborhood 526: 164804.51 units
#   Neighborhood 527: 1.10132634e6 units
#   Neighborhood 529: 2.2635378e6 units
#   Neighborhood 532: 209126.85 units
#   Neighborhood 533: 527148.97 units
#   Neighborhood 543: 309269.1 units
#   Neighborhood 552: 121379.77 units
#   Neighborhood 561: 107718.21 units
#   Neighborhood 581: 252089.29 units
#   Neighborhood 585: 37083.23 units
#
# Total neighborhoods receiving any food: 110
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 4.0, w_eq = 1.0 ===
# Total miles driven (transport cost, no penalty): 6.981514e6
# Worst remaining deficit: 2.66897301e6 units in neighborhood 129
#
# Neighborhoods that received food:
#
#   Neighborhood 1: 102142.62 units
#   Neighborhood 2: 333492.65 units
#   Neighborhood 4: 113652.81 units
#   Neighborhood 8: 113911.46 units
#   Neighborhood 20: 23547.32 units
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 1.18393395e6 units
#   Neighborhood 40: 40369.71 units
#   Neighborhood 50: 105498.51 units
#   Neighborhood 56: 979114.69 units
#   Neighborhood 59: 23285.42 units
#   Neighborhood 80: 238489.99 units
#   Neighborhood 93: 89959.74 units
#   Neighborhood 101: 704873.88 units
#   Neighborhood 111: 258687.53 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 115: 175960.45 units
#   Neighborhood 118: 261754.51 units
#   Neighborhood 120: 405519.22 units
#   Neighborhood 124: 2162.6 units
#   Neighborhood 129: 262935.86 units
#   Neighborhood 135: 363136.01 units
#   Neighborhood 147: 272014.5 units
#   Neighborhood 155: 720808.95 units
#   Neighborhood 156: 2.50267088e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 163: 105866.87 units
#   Neighborhood 166: 1.82301116e6 units
#   Neighborhood 168: 2.09885694e6 units
#   Neighborhood 174: 91166.72 units
#   Neighborhood 175: 985286.69 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 191: 2.28344722e6 units
#   Neighborhood 194: 311007.77 units
#   Neighborhood 196: 768251.57 units
#   Neighborhood 197: 797194.91 units
#   Neighborhood 203: 13128.31 units
#   Neighborhood 207: 2.46610213e6 units
#   Neighborhood 209: 373365.51 units
#   Neighborhood 221: 404200.91 units
#   Neighborhood 222: 56409.56 units
#   Neighborhood 223: 560298.34 units
#   Neighborhood 233: 275925.93 units
#   Neighborhood 236: 424811.03 units
#   Neighborhood 237: 509307.12 units
#   Neighborhood 242: 2.2632048e6 units
#   Neighborhood 244: 737793.87 units
#   Neighborhood 245: 1.04713999e6 units
#   Neighborhood 246: 1.37776219e6 units
#   Neighborhood 247: 1.15737126e6 units
#   Neighborhood 248: 513481.37 units
#   Neighborhood 250: 1.60917574e6 units
#   Neighborhood 252: 1.57633239e6 units
#   Neighborhood 253: 690257.6 units
#   Neighborhood 254: 1.46609475e6 units
#   Neighborhood 255: 2.03696497e6 units
#   Neighborhood 269: 130707.95 units
#   Neighborhood 277: 88214.41 units
#   Neighborhood 313: 1.23241672e6 units
#   Neighborhood 319: 624041.39 units
#   Neighborhood 324: 3.54929376e6 units
#   Neighborhood 325: 129753.36 units
#   Neighborhood 326: 104606.61 units
#   Neighborhood 327: 557994.27 units
#   Neighborhood 336: 481957.93 units
#   Neighborhood 346: 311932.67 units
#   Neighborhood 352: 764128.09 units
#   Neighborhood 355: 196114.86 units
#   Neighborhood 364: 955203.79 units
#   Neighborhood 367: 246155.18 units
#   Neighborhood 379: 237746.9 units
#   Neighborhood 380: 66997.76 units
#   Neighborhood 381: 124780.28 units
#   Neighborhood 384: 722445.96 units
#   Neighborhood 400: 82217.31 units
#   Neighborhood 401: 225650.67 units
#   Neighborhood 402: 904474.36 units
#   Neighborhood 404: 1.17085996e6 units
#   Neighborhood 417: 255191.16 units
#   Neighborhood 430: 412136.38 units
#   Neighborhood 434: 77079.76 units
#   Neighborhood 439: 1.88955793e6 units
#   Neighborhood 441: 156023.38 units
#   Neighborhood 442: 810537.52 units
#   Neighborhood 443: 575068.83 units
#   Neighborhood 444: 319917.59 units
#   Neighborhood 447: 81173.04 units
#   Neighborhood 449: 1.54032922e6 units
#   Neighborhood 450: 882935.48 units
#   Neighborhood 451: 1.18576355e6 units
#   Neighborhood 452: 1.73749145e6 units
#   Neighborhood 474: 478056.68 units
#   Neighborhood 479: 196019.04 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 516: 180238.28 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 1.00167224e6 units
#   Neighborhood 526: 164804.51 units
#   Neighborhood 527: 1.10132634e6 units
#   Neighborhood 529: 2.2635378e6 units
#   Neighborhood 532: 209126.85 units
#   Neighborhood 533: 527148.97 units
#   Neighborhood 543: 309269.1 units
#   Neighborhood 549: 70347.64 units
#   Neighborhood 552: 121379.77 units
#   Neighborhood 561: 214025.13 units
#   Neighborhood 577: 586197.94 units
#   Neighborhood 581: 252089.29 units
#   Neighborhood 585: 37083.23 units
#
# Total neighborhoods receiving any food: 113
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 3.0, w_eq = 1.0 ===
# Total miles driven (transport cost, no penalty): 6.994308e6
# Worst remaining deficit: 2.62505191e6 units in neighborhood 129
#
# Neighborhoods that received food:
#
#   Neighborhood 1: 102142.62 units
#   Neighborhood 2: 333492.65 units
#   Neighborhood 4: 113652.81 units
#   Neighborhood 8: 113911.46 units
#   Neighborhood 20: 23547.32 units
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 1.18393395e6 units
#   Neighborhood 40: 40369.71 units
#   Neighborhood 50: 105498.51 units
#   Neighborhood 56: 979114.69 units
#   Neighborhood 59: 23285.42 units
#   Neighborhood 80: 238489.99 units
#   Neighborhood 93: 89959.74 units
#   Neighborhood 101: 704873.88 units
#   Neighborhood 111: 258687.53 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 115: 175960.45 units
#   Neighborhood 118: 261754.51 units
#   Neighborhood 120: 405519.22 units
#   Neighborhood 124: 2162.6 units
#   Neighborhood 129: 306856.96 units
#   Neighborhood 135: 363136.01 units
#   Neighborhood 147: 272014.5 units
#   Neighborhood 155: 720808.95 units
#   Neighborhood 156: 2.50267088e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 163: 105866.87 units
#   Neighborhood 166: 884585.36 units
#   Neighborhood 168: 2.09885694e6 units
#   Neighborhood 175: 985286.69 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 191: 2.28344722e6 units
#   Neighborhood 194: 311007.77 units
#   Neighborhood 196: 812172.67 units
#   Neighborhood 197: 797194.91 units
#   Neighborhood 203: 13128.31 units
#   Neighborhood 207: 2.46610213e6 units
#   Neighborhood 209: 373365.51 units
#   Neighborhood 221: 404200.91 units
#   Neighborhood 222: 56409.56 units
#   Neighborhood 223: 560298.34 units
#   Neighborhood 233: 474243.0 units
#   Neighborhood 236: 424811.03 units
#   Neighborhood 237: 509307.12 units
#   Neighborhood 242: 2.2632048e6 units
#   Neighborhood 244: 737793.87 units
#   Neighborhood 245: 1.04713999e6 units
#   Neighborhood 246: 1.37776219e6 units
#   Neighborhood 247: 1.15737126e6 units
#   Neighborhood 248: 557402.47 units
#   Neighborhood 250: 1.65309683e6 units
#   Neighborhood 252: 1.57633239e6 units
#   Neighborhood 253: 690257.6 units
#   Neighborhood 254: 1.46609475e6 units
#   Neighborhood 255: 2.03696497e6 units
#   Neighborhood 269: 130707.95 units
#   Neighborhood 277: 88214.41 units
#   Neighborhood 313: 1.23241672e6 units
#   Neighborhood 319: 624041.39 units
#   Neighborhood 324: 3.54929376e6 units
#   Neighborhood 325: 129753.36 units
#   Neighborhood 326: 104606.61 units
#   Neighborhood 327: 557994.27 units
#   Neighborhood 336: 481957.93 units
#   Neighborhood 346: 311932.67 units
#   Neighborhood 352: 808049.19 units
#   Neighborhood 355: 196114.86 units
#   Neighborhood 364: 999124.89 units
#   Neighborhood 367: 290076.28 units
#   Neighborhood 379: 237746.9 units
#   Neighborhood 381: 124780.28 units
#   Neighborhood 384: 722445.96 units
#   Neighborhood 400: 82217.31 units
#   Neighborhood 401: 225650.67 units
#   Neighborhood 402: 904474.36 units
#   Neighborhood 404: 1.17085996e6 units
#   Neighborhood 417: 255191.16 units
#   Neighborhood 430: 304986.03 units
#   Neighborhood 434: 77079.76 units
#   Neighborhood 439: 1.88955793e6 units
#   Neighborhood 441: 156023.38 units
#   Neighborhood 442: 810537.52 units
#   Neighborhood 443: 575068.83 units
#   Neighborhood 444: 319917.59 units
#   Neighborhood 447: 125094.14 units
#   Neighborhood 449: 1.54032922e6 units
#   Neighborhood 450: 882935.48 units
#   Neighborhood 451: 1.18576355e6 units
#   Neighborhood 452: 1.73749145e6 units
#   Neighborhood 474: 478056.68 units
#   Neighborhood 479: 196019.04 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 516: 180238.28 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 1.00167224e6 units
#   Neighborhood 526: 164804.51 units
#   Neighborhood 527: 1.10132634e6 units
#   Neighborhood 529: 2.2635378e6 units
#   Neighborhood 532: 209126.85 units
#   Neighborhood 533: 527148.97 units
#   Neighborhood 543: 309269.1 units
#   Neighborhood 552: 121379.77 units
#   Neighborhood 561: 257946.23 units
#   Neighborhood 577: 1.26667925e6 units
#   Neighborhood 581: 252089.29 units
#   Neighborhood 585: 37083.23 units
#
# Total neighborhoods receiving any food: 110
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 2.0, w_eq = 1.0 ===
# Total miles driven (transport cost, no penalty): 7.112076e6
# Worst remaining deficit: 2.35296154e6 units in neighborhood 129
#
# Neighborhoods that received food:
#
#   Neighborhood 1: 102142.62 units
#   Neighborhood 2: 333492.65 units
#   Neighborhood 4: 113652.81 units
#   Neighborhood 8: 113911.46 units
#   Neighborhood 20: 23547.32 units
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 1.18393395e6 units
#   Neighborhood 40: 40369.71 units
#   Neighborhood 50: 105498.51 units
#   Neighborhood 56: 979114.69 units
#   Neighborhood 59: 23285.42 units
#   Neighborhood 80: 238489.99 units
#   Neighborhood 93: 89959.74 units
#   Neighborhood 101: 704873.88 units
#   Neighborhood 111: 258687.53 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 118: 261754.51 units
#   Neighborhood 120: 405519.22 units
#   Neighborhood 129: 578947.32 units
#   Neighborhood 135: 363136.01 units
#   Neighborhood 147: 272014.5 units
#   Neighborhood 155: 720808.95 units
#   Neighborhood 156: 2.50267088e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 163: 105866.87 units
#   Neighborhood 166: 534553.88 units
#   Neighborhood 168: 2.09885694e6 units
#   Neighborhood 174: 631731.51 units
#   Neighborhood 175: 985286.69 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 183: 208554.95 units
#   Neighborhood 191: 2.28344722e6 units
#   Neighborhood 194: 311007.77 units
#   Neighborhood 196: 1.08426304e6 units
#   Neighborhood 197: 797194.91 units
#   Neighborhood 203: 13128.31 units
#   Neighborhood 207: 2.46610213e6 units
#   Neighborhood 209: 373365.51 units
#   Neighborhood 221: 404200.91 units
#   Neighborhood 222: 56409.56 units
#   Neighborhood 223: 560298.34 units
#   Neighborhood 236: 424811.03 units
#   Neighborhood 237: 509307.12 units
#   Neighborhood 242: 2.2632048e6 units
#   Neighborhood 244: 737793.87 units
#   Neighborhood 245: 1.04713999e6 units
#   Neighborhood 246: 1.37776219e6 units
#   Neighborhood 247: 363026.95 units
#   Neighborhood 248: 829492.83 units
#   Neighborhood 250: 1.9251872e6 units
#   Neighborhood 252: 1.57633239e6 units
#   Neighborhood 253: 690257.6 units
#   Neighborhood 254: 1.46609475e6 units
#   Neighborhood 255: 2.03696497e6 units
#   Neighborhood 269: 130707.95 units
#   Neighborhood 277: 88214.41 units
#   Neighborhood 313: 1.23241672e6 units
#   Neighborhood 319: 624041.39 units
#   Neighborhood 324: 3.54929376e6 units
#   Neighborhood 325: 129753.36 units
#   Neighborhood 326: 104606.61 units
#   Neighborhood 327: 557994.27 units
#   Neighborhood 336: 481957.93 units
#   Neighborhood 352: 1.08013956e6 units
#   Neighborhood 364: 1.27121526e6 units
#   Neighborhood 367: 562166.65 units
#   Neighborhood 379: 237746.9 units
#   Neighborhood 380: 893773.78 units
#   Neighborhood 381: 124780.28 units
#   Neighborhood 384: 722445.96 units
#   Neighborhood 400: 82217.31 units
#   Neighborhood 401: 225650.67 units
#   Neighborhood 402: 904474.36 units
#   Neighborhood 404: 1.17085996e6 units
#   Neighborhood 417: 255191.16 units
#   Neighborhood 434: 77079.76 units
#   Neighborhood 439: 1.88955793e6 units
#   Neighborhood 441: 156023.38 units
#   Neighborhood 442: 810537.52 units
#   Neighborhood 443: 575068.83 units
#   Neighborhood 444: 279347.42 units
#   Neighborhood 447: 397184.51 units
#   Neighborhood 449: 1.54032922e6 units
#   Neighborhood 450: 882935.48 units
#   Neighborhood 451: 1.18576355e6 units
#   Neighborhood 452: 1.73749145e6 units
#   Neighborhood 474: 478056.68 units
#   Neighborhood 479: 196019.04 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 516: 180238.28 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 1.00167224e6 units
#   Neighborhood 526: 164804.51 units
#   Neighborhood 527: 1.10132634e6 units
#   Neighborhood 529: 2.2635378e6 units
#   Neighborhood 532: 209126.85 units
#   Neighborhood 533: 527148.97 units
#   Neighborhood 549: 115826.2 units
#   Neighborhood 561: 530036.6 units
#   Neighborhood 577: 48973.94 units
#   Neighborhood 581: 252089.29 units
#   Neighborhood 585: 37083.23 units
#
# Total neighborhoods receiving any food: 106
#
# === Summary table over all weights ===
# 19×7 DataFrame
#  Row │ w_cost   w_eq     obj_value   cost_value  equity_t        total_recv  total_unmet
#      │ Float64  Float64  Float64     Float64     Float64         Float64     Float64
# ─────┼───────────────────────────────────────────────────────────────────────────────────
#    1 │     1.0      1.0  1.17919e16  1.17919e16       2.01461e6   7.50849e7    7.73545e7
#    2 │     1.0      2.0  1.17919e16  1.17919e16       1.34038e6   7.50849e7    7.73545e7
#    3 │     1.0      3.0  1.17919e16  1.17919e16       1.13421e6   7.50849e7    7.73545e7
#    4 │     1.0      4.0  1.17919e16  1.17919e16  974883.0         7.50849e7    7.73545e7
#    5 │     1.0      5.0  1.17919e16  1.17919e16       9.10017e5   7.50849e7    7.73545e7
#    6 │     1.0      6.0  1.17919e16  1.17919e16       8.47789e5   7.50849e7    7.73545e7
#    7 │     1.0      7.0  1.17919e16  1.17919e16       8.10974e5   7.50849e7    7.73545e7
#    8 │     1.0      8.0  1.17919e16  1.17919e16       7.97195e5   7.50849e7    7.73545e7
#    9 │     1.0      9.0  1.17919e16  1.17919e16       7.94577e5   7.50849e7    7.73545e7
#   10 │     1.0     10.0  1.17919e16  1.17919e16       7.31641e5   7.50849e7    7.73545e7
#   11 │    10.0      1.0  1.17919e17  1.17919e16       2.91513e6   7.50849e7    7.73545e7
#   12 │     9.0      1.0  1.06127e17  1.17919e16       2.89865e6   7.50849e7    7.73545e7
#   13 │     8.0      1.0  9.43349e16  1.17919e16       2.89865e6   7.50849e7    7.73545e7
#   14 │     7.0      1.0  8.2543e16   1.17919e16       2.883e6     7.50849e7    7.73545e7
#   15 │     6.0      1.0  7.07512e16  1.17919e16       2.84909e6   7.50849e7    7.73545e7
#   16 │     5.0      1.0  5.89593e16  1.17919e16       2.77528e6   7.50849e7    7.73545e7
#   17 │     4.0      1.0  4.71674e16  1.17919e16       2.66897e6   7.50849e7    7.73545e7
#   18 │     3.0      1.0  3.53756e16  1.17919e16       2.62505e6   7.50849e7    7.73545e7
#   19 │     2.0      1.0  2.35837e16  1.17919e16       2.35296e6   7.50849e7    7.73545e7

# %%
results = DataFrame(
    w_cost      = Float64[],
    w_eq        = Float64[],
    obj_value   = Float64[],
    cost_value  = Float64[],
    equity_t    = Float64[],
    total_recv  = Float64[],
    total_unmet = Float64[],
)

# 1:1, 1:2, ..., 1:10
for w_eq_int in 1:10
    w_cost = 1.0
    w_eq   = float(w_eq_int)

    model, x, y, u, r, t, cost_expr, equity_expr = build_combined_model(w_cost, w_eq)
    optimize!(model)

    if termination_status(model) != MOI.OPTIMAL
        println("Weights (", w_cost, ", ", w_eq, ") not optimal, status = ", termination_status(model))
        continue
    end

    obj_val    = objective_value(model)
    cost_val   = value(cost_expr)
    t_val      = value(t)
    r_vals     = value.(r)
    u_vals     = value.(u)
    total_d    = sum(demand)
    total_recv = sum(r_vals)
    total_unm  = total_d - total_recv

    transport_cost = cost_val - M * sum(u_vals)
    unmet_by_k = demand .- r_vals
    max_unmet, worst_k = findmax(unmet_by_k)

    push!(results, (w_cost, w_eq, obj_val, cost_val, t_val, total_recv, total_unm))

    println("\n=== Weights: w_cost = $(w_cost), w_eq = $(w_eq) ===")
    println("Total miles driven (transport cost, no penalty): ",
            round(transport_cost, digits = 2))
    println("Worst remaining deficit: ",
            round(max_unmet, digits = 2),
            " units in neighborhood ", worst_k)

    println("Total food given away: ",
               round(total_recv, digits = 2), " units")

    println("\nNeighborhoods that received food:\n")

    count_nonzero = 0
    for k in 1:N
        if r_vals[k] > 1e-6
            count_nonzero += 1
            println("  Neighborhood $(k): $(round(r_vals[k], digits=2)) units")
        end
    end

    println("\nTotal neighborhoods receiving any food: $count_nonzero\n")
end

# 10:1, 9:1, ..., 2:1
for w_cost_int in 10:-1:2
    w_eq   = 1.0
    w_cost = float(w_cost_int)

    model, x, y, u, r, t, cost_expr, equity_expr = build_combined_model(w_cost, w_eq)
    optimize!(model)

    if termination_status(model) != MOI.OPTIMAL
        println("Weights (", w_cost, ", ", w_eq, ") not optimal, status = ", termination_status(model))
        continue
    end

    obj_val    = objective_value(model)
    cost_val   = value(cost_expr)
    t_val      = value(t)
    r_vals     = value.(r)
    u_vals     = value.(u)
    total_d    = sum(demand)
    total_recv = sum(r_vals)
    total_unm  = total_d - total_recv

    transport_cost = cost_val - M * sum(u_vals)
    unmet_by_k = demand .- r_vals
    max_unmet, worst_k = findmax(unmet_by_k)

    push!(results, (w_cost, w_eq, obj_val, cost_val, t_val, total_recv, total_unm))

    println("\n=== Weights: w_cost = $(w_cost), w_eq = $(w_eq) ===")
    println("Total miles driven (transport cost, no penalty): ",
            round(transport_cost, digits = 2))
    println("Worst remaining deficit: ",
            round(max_unmet, digits = 2),
            " units in neighborhood ", worst_k)

    println("Total food given away: ",
               round(total_recv, digits = 2), " units")

    println("\nNeighborhoods that received food:\n")

    count_nonzero = 0
    for k in 1:N
        if r_vals[k] > 1e-6
            count_nonzero += 1
            println("  Neighborhood $(k): $(round(r_vals[k], digits=2)) units")
        end
    end

    println("\nTotal neighborhoods receiving any food: $count_nonzero\n")
end

println("=== Summary table over all weights ===")
println(results)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 1.0, w_eq = 1.0 ===
# Total miles driven (transport cost, no penalty): 7.373734e6
# Worst remaining deficit: 2.01461008e6 units in neighborhood 250
# Total food given away: 7.508486888e7 units
#
# Neighborhoods that received food:
#
#   Neighborhood 1: 102142.62 units
#   Neighborhood 2: 333492.65 units
#   Neighborhood 4: 113652.81 units
#   Neighborhood 8: 113911.46 units
#   Neighborhood 20: 23547.32 units
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 1.18393395e6 units
#   Neighborhood 40: 40369.71 units
#   Neighborhood 50: 105498.51 units
#   Neighborhood 59: 23285.42 units
#   Neighborhood 69: 216784.09 units
#   Neighborhood 80: 238489.99 units
#   Neighborhood 93: 89959.74 units
#   Neighborhood 101: 704873.88 units
#   Neighborhood 111: 258687.53 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 118: 261754.51 units
#   Neighborhood 120: 405519.22 units
#   Neighborhood 129: 917298.78 units
#   Neighborhood 135: 363136.01 units
#   Neighborhood 141: 48614.39 units
#   Neighborhood 147: 272014.5 units
#   Neighborhood 155: 720808.95 units
#   Neighborhood 156: 2.50267088e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 163: 105866.87 units
#   Neighborhood 165: 154945.7 units
#   Neighborhood 166: 705230.37 units
#   Neighborhood 168: 2.09885694e6 units
#   Neighborhood 172: 314385.12 units
#   Neighborhood 174: 502559.5 units
#   Neighborhood 175: 964596.0 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 183: 546906.41 units
#   Neighborhood 191: 2.28344722e6 units
#   Neighborhood 195: 315429.26 units
#   Neighborhood 196: 1.4226145e6 units
#   Neighborhood 197: 797194.91 units
#   Neighborhood 203: 13128.31 units
#   Neighborhood 207: 2.46610213e6 units
#   Neighborhood 209: 373365.51 units
#   Neighborhood 221: 404200.91 units
#   Neighborhood 222: 56409.56 units
#   Neighborhood 223: 560298.34 units
#   Neighborhood 236: 424811.03 units
#   Neighborhood 237: 509307.12 units
#   Neighborhood 242: 2.2632048e6 units
#   Neighborhood 244: 737793.87 units
#   Neighborhood 246: 1.37776219e6 units
#   Neighborhood 248: 1.16784429e6 units
#   Neighborhood 250: 2.26353866e6 units
#   Neighborhood 252: 1.57633239e6 units
#   Neighborhood 253: 690257.6 units
#   Neighborhood 254: 1.46609475e6 units
#   Neighborhood 255: 2.03696497e6 units
#   Neighborhood 269: 130707.95 units
#   Neighborhood 277: 88214.41 units
#   Neighborhood 313: 1.23241672e6 units
#   Neighborhood 319: 624041.39 units
#   Neighborhood 324: 3.54929376e6 units
#   Neighborhood 325: 129753.36 units
#   Neighborhood 326: 104606.61 units
#   Neighborhood 327: 557994.27 units
#   Neighborhood 336: 481957.93 units
#   Neighborhood 352: 1.41849102e6 units
#   Neighborhood 364: 1.60956671e6 units
#   Neighborhood 367: 900518.11 units
#   Neighborhood 379: 237746.9 units
#   Neighborhood 380: 149210.5 units
#   Neighborhood 381: 124780.28 units
#   Neighborhood 384: 722445.96 units
#   Neighborhood 400: 82217.31 units
#   Neighborhood 401: 225650.67 units
#   Neighborhood 402: 904474.36 units
#   Neighborhood 404: 1.17085996e6 units
#   Neighborhood 417: 255191.16 units
#   Neighborhood 434: 77079.76 units
#   Neighborhood 439: 1.88955793e6 units
#   Neighborhood 441: 156023.38 units
#   Neighborhood 443: 575068.83 units
#   Neighborhood 447: 735535.97 units
#   Neighborhood 449: 1.54032922e6 units
#   Neighborhood 450: 882935.48 units
#   Neighborhood 451: 1.18576355e6 units
#   Neighborhood 452: 1.73749145e6 units
#   Neighborhood 474: 478056.68 units
#   Neighborhood 479: 196019.04 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 516: 180238.28 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 1.00167224e6 units
#   Neighborhood 526: 164804.51 units
#   Neighborhood 527: 1.10132634e6 units
#   Neighborhood 529: 2.2635378e6 units
#   Neighborhood 533: 527148.97 units
#   Neighborhood 549: 454177.66 units
#   Neighborhood 561: 868388.06 units
#   Neighborhood 581: 252089.29 units
#   Neighborhood 585: 37083.23 units
#
# Total neighborhoods receiving any food: 103
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 1.0, w_eq = 2.0 ===
# Total miles driven (transport cost, no penalty): 8.386632e6
# Worst remaining deficit: 1.34037731e6 units in neighborhood 69
# Total food given away: 7.508486888e7 units
#
# Neighborhoods that received food:
#
#   Neighborhood 1: 102142.62 units
#   Neighborhood 2: 321686.31 units
#   Neighborhood 4: 113652.81 units
#   Neighborhood 20: 23547.32 units
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 1.18393395e6 units
#   Neighborhood 40: 40369.71 units
#   Neighborhood 50: 105498.51 units
#   Neighborhood 59: 23285.42 units
#   Neighborhood 69: 891016.87 units
#   Neighborhood 80: 238489.99 units
#   Neighborhood 93: 89959.74 units
#   Neighborhood 101: 704873.88 units
#   Neighborhood 111: 258687.53 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 129: 1.59153155e6 units
#   Neighborhood 135: 363136.01 units
#   Neighborhood 140: 161875.1 units
#   Neighborhood 141: 722847.17 units
#   Neighborhood 147: 272014.5 units
#   Neighborhood 155: 54585.89 units
#   Neighborhood 156: 2.50267088e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 163: 105866.87 units
#   Neighborhood 165: 829178.48 units
#   Neighborhood 166: 482633.86 units
#   Neighborhood 168: 2.09885694e6 units
#   Neighborhood 172: 988617.89 units
#   Neighborhood 174: 502559.5 units
#   Neighborhood 179: 23864.1 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 183: 1.22113918e6 units
#   Neighborhood 191: 943069.91 units
#   Neighborhood 195: 989662.04 units
#   Neighborhood 196: 2.09684727e6 units
#   Neighborhood 197: 448536.73 units
#   Neighborhood 203: 13128.31 units
#   Neighborhood 207: 2.46610213e6 units
#   Neighborhood 209: 373365.51 units
#   Neighborhood 211: 183245.91 units
#   Neighborhood 221: 404200.91 units
#   Neighborhood 222: 56409.56 units
#   Neighborhood 223: 560298.34 units
#   Neighborhood 237: 509307.12 units
#   Neighborhood 242: 922827.49 units
#   Neighborhood 244: 737793.87 units
#   Neighborhood 246: 37384.88 units
#   Neighborhood 248: 1.84207706e6 units
#   Neighborhood 250: 2.93777143e6 units
#   Neighborhood 252: 1.57633239e6 units
#   Neighborhood 254: 125717.44 units
#   Neighborhood 255: 2.03696497e6 units
#   Neighborhood 269: 130707.95 units
#   Neighborhood 277: 88214.41 units
#   Neighborhood 313: 1.23241672e6 units
#   Neighborhood 319: 624041.39 units
#   Neighborhood 324: 3.54929376e6 units
#   Neighborhood 325: 129753.36 units
#   Neighborhood 326: 104606.61 units
#   Neighborhood 327: 557994.27 units
#   Neighborhood 352: 2.09272379e6 units
#   Neighborhood 363: 658173.87 units
#   Neighborhood 364: 2.28379949e6 units
#   Neighborhood 367: 1.57475088e6 units
#   Neighborhood 371: 290533.84 units
#   Neighborhood 380: 561049.68 units
#   Neighborhood 384: 722445.96 units
#   Neighborhood 400: 82217.31 units
#   Neighborhood 401: 225650.67 units
#   Neighborhood 402: 904474.36 units
#   Neighborhood 404: 1.17085996e6 units
#   Neighborhood 417: 255191.16 units
#   Neighborhood 434: 77079.76 units
#   Neighborhood 439: 549180.62 units
#   Neighborhood 441: 156023.38 units
#   Neighborhood 445: 674232.77 units
#   Neighborhood 447: 1.40976874e6 units
#   Neighborhood 449: 1.54032922e6 units
#   Neighborhood 452: 1.73749145e6 units
#   Neighborhood 474: 478056.68 units
#   Neighborhood 479: 196019.04 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 516: 180238.28 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 1.00167224e6 units
#   Neighborhood 526: 164804.51 units
#   Neighborhood 527: 1.10132634e6 units
#   Neighborhood 529: 2.2635378e6 units
#   Neighborhood 549: 1.12841043e6 units
#   Neighborhood 560: 522387.67 units
#   Neighborhood 561: 1.54262083e6 units
#   Neighborhood 564: 655645.12 units
#   Neighborhood 581: 709989.79 units
#   Neighborhood 585: 37083.23 units
#
# Total neighborhoods receiving any food: 98
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 1.0, w_eq = 3.0 ===
# Total miles driven (transport cost, no penalty): 8.895466e6
# Worst remaining deficit: 1.13421375e6 units in neighborhood 352
# Total food given away: 7.508486888e7 units
#
# Neighborhoods that received food:
#
#   Neighborhood 1: 102142.62 units
#   Neighborhood 2: 234918.93 units
#   Neighborhood 4: 113652.81 units
#   Neighborhood 20: 23547.32 units
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 1.18393395e6 units
#   Neighborhood 50: 105498.51 units
#   Neighborhood 59: 23285.42 units
#   Neighborhood 69: 1.09718042e6 units
#   Neighborhood 80: 238489.99 units
#   Neighborhood 93: 89959.74 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 129: 1.79769511e6 units
#   Neighborhood 135: 363136.01 units
#   Neighborhood 140: 368038.65 units
#   Neighborhood 141: 929010.72 units
#   Neighborhood 147: 272014.5 units
#   Neighborhood 155: 720808.95 units
#   Neighborhood 156: 2.50267088e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 162: 74667.07 units
#   Neighborhood 163: 105866.87 units
#   Neighborhood 165: 1.03534203e6 units
#   Neighborhood 166: 688797.41 units
#   Neighborhood 168: 964643.18 units
#   Neighborhood 172: 1.19478145e6 units
#   Neighborhood 174: 502559.5 units
#   Neighborhood 179: 230027.66 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 183: 1.42730274e6 units
#   Neighborhood 191: 1.14923347e6 units
#   Neighborhood 195: 1.19582559e6 units
#   Neighborhood 196: 2.30301083e6 units
#   Neighborhood 203: 13128.31 units
#   Neighborhood 207: 2.46610213e6 units
#   Neighborhood 210: 32270.68 units
#   Neighborhood 211: 389409.47 units
#   Neighborhood 221: 404200.91 units
#   Neighborhood 222: 56409.56 units
#   Neighborhood 223: 560298.34 units
#   Neighborhood 242: 1.12899104e6 units
#   Neighborhood 246: 243548.44 units
#   Neighborhood 247: 23157.51 units
#   Neighborhood 248: 2.04824062e6 units
#   Neighborhood 250: 3.14393499e6 units
#   Neighborhood 252: 1.57633239e6 units
#   Neighborhood 254: 331881.0 units
#   Neighborhood 255: 1.25815696e6 units
#   Neighborhood 269: 130707.95 units
#   Neighborhood 277: 88214.41 units
#   Neighborhood 313: 1.23241672e6 units
#   Neighborhood 319: 624041.39 units
#   Neighborhood 324: 3.54929376e6 units
#   Neighborhood 325: 129753.36 units
#   Neighborhood 326: 104606.61 units
#   Neighborhood 327: 557994.27 units
#   Neighborhood 352: 2.29888735e6 units
#   Neighborhood 363: 864337.42 units
#   Neighborhood 364: 2.48996304e6 units
#   Neighborhood 367: 1.78091443e6 units
#   Neighborhood 368: 165227.97 units
#   Neighborhood 371: 496697.4 units
#   Neighborhood 373: 157786.85 units
#   Neighborhood 380: 767213.23 units
#   Neighborhood 384: 250735.93 units
#   Neighborhood 400: 82217.31 units
#   Neighborhood 401: 225650.67 units
#   Neighborhood 402: 904474.36 units
#   Neighborhood 404: 1.17085996e6 units
#   Neighborhood 417: 255191.16 units
#   Neighborhood 439: 755344.18 units
#   Neighborhood 445: 880396.33 units
#   Neighborhood 447: 1.61593229e6 units
#   Neighborhood 449: 1.54032922e6 units
#   Neighborhood 451: 51549.79 units
#   Neighborhood 452: 1.73749145e6 units
#   Neighborhood 474: 405378.23 units
#   Neighborhood 479: 196019.04 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 516: 180238.28 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 1.00167224e6 units
#   Neighborhood 526: 164804.51 units
#   Neighborhood 527: 1.10132634e6 units
#   Neighborhood 529: 1.12932405e6 units
#   Neighborhood 549: 1.33457398e6 units
#   Neighborhood 560: 728551.22 units
#   Neighborhood 561: 1.74878438e6 units
#   Neighborhood 564: 861808.68 units
#   Neighborhood 577: 132465.49 units
#   Neighborhood 585: 37083.23 units
#
# Total neighborhoods receiving any food: 95
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 1.0, w_eq = 4.0 ===
# Total miles driven (transport cost, no penalty): 9.444624e6
# Worst remaining deficit: 974883.05 units in neighborhood 196
# Total food given away: 7.508486888e7 units
#
# Neighborhoods that received food:
#
#   Neighborhood 1: 102142.62 units
#   Neighborhood 2: 208033.49 units
#   Neighborhood 4: 113652.81 units
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 1.18393395e6 units
#   Neighborhood 50: 105498.51 units
#   Neighborhood 56: 4231.64 units
#   Neighborhood 59: 23285.42 units
#   Neighborhood 69: 1.25651113e6 units
#   Neighborhood 93: 89959.74 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 129: 1.95702582e6 units
#   Neighborhood 135: 363136.01 units
#   Neighborhood 140: 527369.36 units
#   Neighborhood 141: 1.08834143e6 units
#   Neighborhood 147: 272014.5 units
#   Neighborhood 155: 306918.76 units
#   Neighborhood 156: 1.52778783e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 162: 233997.77 units
#   Neighborhood 163: 105866.87 units
#   Neighborhood 165: 1.19467274e6 units
#   Neighborhood 166: 848128.12 units
#   Neighborhood 168: 1.12397389e6 units
#   Neighborhood 172: 1.35411215e6 units
#   Neighborhood 174: 256882.43 units
#   Neighborhood 175: 10403.64 units
#   Neighborhood 179: 389358.36 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 183: 1.58663345e6 units
#   Neighborhood 191: 1.30856418e6 units
#   Neighborhood 195: 1.3551563e6 units
#   Neighborhood 196: 2.46234153e6 units
#   Neighborhood 203: 13128.31 units
#   Neighborhood 207: 1.49121908e6 units
#   Neighborhood 210: 191601.39 units
#   Neighborhood 211: 548740.17 units
#   Neighborhood 242: 1.28832175e6 units
#   Neighborhood 245: 72256.94 units
#   Neighborhood 246: 402879.14 units
#   Neighborhood 247: 182488.21 units
#   Neighborhood 248: 2.20757132e6 units
#   Neighborhood 250: 3.30326569e6 units
#   Neighborhood 252: 1.57633239e6 units
#   Neighborhood 254: 491211.7 units
#   Neighborhood 255: 1.06208192e6 units
#   Neighborhood 269: 130707.95 units
#   Neighborhood 277: 88214.41 units
#   Neighborhood 313: 1.23241672e6 units
#   Neighborhood 319: 624041.39 units
#   Neighborhood 324: 3.54929376e6 units
#   Neighborhood 325: 129753.36 units
#   Neighborhood 326: 104606.61 units
#   Neighborhood 327: 557994.27 units
#   Neighborhood 352: 2.45821805e6 units
#   Neighborhood 363: 1.02366813e6 units
#   Neighborhood 364: 2.64929375e6 units
#   Neighborhood 366: 159330.71 units
#   Neighborhood 367: 1.94024514e6 units
#   Neighborhood 368: 324558.68 units
#   Neighborhood 371: 656028.1 units
#   Neighborhood 373: 317117.56 units
#   Neighborhood 380: 926543.94 units
#   Neighborhood 384: 664626.12 units
#   Neighborhood 400: 82217.31 units
#   Neighborhood 401: 225650.67 units
#   Neighborhood 402: 904474.36 units
#   Neighborhood 404: 195976.91 units
#   Neighborhood 417: 255191.16 units
#   Neighborhood 439: 914674.88 units
#   Neighborhood 445: 1.03972703e6 units
#   Neighborhood 447: 1.775263e6 units
#   Neighborhood 449: 1.54032922e6 units
#   Neighborhood 451: 210880.5 units
#   Neighborhood 452: 762608.4 units
#   Neighborhood 474: 405378.23 units
#   Neighborhood 479: 196019.04 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 516: 180238.28 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 1.00167224e6 units
#   Neighborhood 526: 164804.51 units
#   Neighborhood 527: 126443.3 units
#   Neighborhood 529: 1.28865475e6 units
#   Neighborhood 549: 1.49390469e6 units
#   Neighborhood 560: 887881.93 units
#   Neighborhood 561: 1.90811509e6 units
#   Neighborhood 564: 1.02113938e6 units
#   Neighborhood 568: 6547.77 units
#   Neighborhood 577: 291796.2 units
#   Neighborhood 585: 37083.23 units
#
# Total neighborhoods receiving any food: 95
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 1.0, w_eq = 5.0 ===
# Total miles driven (transport cost, no penalty): 9.742846e6
# Worst remaining deficit: 910017.37 units in neighborhood 69
# Total food given away: 7.508486888e7 units
#
# Neighborhoods that received food:
#
#   Neighborhood 1: 102142.62 units
#   Neighborhood 4: 113652.81 units
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 716416.71 units
#   Neighborhood 50: 105498.51 units
#   Neighborhood 56: 69097.32 units
#   Neighborhood 69: 1.3213768e6 units
#   Neighborhood 93: 89959.74 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 129: 2.02189149e6 units
#   Neighborhood 135: 363136.01 units
#   Neighborhood 140: 592235.03 units
#   Neighborhood 141: 1.1532071e6 units
#   Neighborhood 147: 272014.5 units
#   Neighborhood 156: 1.5926535e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 162: 298863.45 units
#   Neighborhood 163: 105866.87 units
#   Neighborhood 165: 1.25953841e6 units
#   Neighborhood 166: 912993.79 units
#   Neighborhood 168: 1.18883956e6 units
#   Neighborhood 172: 1.41897782e6 units
#   Neighborhood 174: 256882.43 units
#   Neighborhood 175: 75269.31 units
#   Neighborhood 179: 454224.04 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 183: 1.65149912e6 units
#   Neighborhood 191: 1.37342985e6 units
#   Neighborhood 195: 1.42002197e6 units
#   Neighborhood 196: 2.52720721e6 units
#   Neighborhood 203: 13128.31 units
#   Neighborhood 207: 1.55608475e6 units
#   Neighborhood 210: 256467.06 units
#   Neighborhood 211: 613605.85 units
#   Neighborhood 242: 1.35318742e6 units
#   Neighborhood 245: 137122.61 units
#   Neighborhood 246: 467744.82 units
#   Neighborhood 247: 247353.89 units
#   Neighborhood 248: 2.272437e6 units
#   Neighborhood 250: 3.36813137e6 units
#   Neighborhood 252: 666315.01 units
#   Neighborhood 254: 556077.38 units
#   Neighborhood 255: 1.1269476e6 units
#   Neighborhood 269: 130707.95 units
#   Neighborhood 277: 88214.41 units
#   Neighborhood 313: 1.23241672e6 units
#   Neighborhood 319: 624041.39 units
#   Neighborhood 324: 3.54929376e6 units
#   Neighborhood 325: 129753.36 units
#   Neighborhood 326: 104606.61 units
#   Neighborhood 327: 557994.27 units
#   Neighborhood 352: 2.52308373e6 units
#   Neighborhood 363: 1.0885338e6 units
#   Neighborhood 364: 2.71415942e6 units
#   Neighborhood 365: 15178.05 units
#   Neighborhood 366: 224196.38 units
#   Neighborhood 367: 2.00511081e6 units
#   Neighborhood 368: 389424.35 units
#   Neighborhood 371: 720893.78 units
#   Neighborhood 373: 381983.23 units
#   Neighborhood 380: 991409.61 units
#   Neighborhood 384: 148942.39 units
#   Neighborhood 400: 82217.31 units
#   Neighborhood 401: 225650.67 units
#   Neighborhood 402: 904474.36 units
#   Neighborhood 404: 260842.59 units
#   Neighborhood 417: 255191.16 units
#   Neighborhood 439: 979540.56 units
#   Neighborhood 445: 1.10459271e6 units
#   Neighborhood 447: 1.84012867e6 units
#   Neighborhood 449: 813262.3 units
#   Neighborhood 451: 275746.17 units
#   Neighborhood 452: 827474.07 units
#   Neighborhood 474: 405378.23 units
#   Neighborhood 479: 196019.04 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 516: 180238.28 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 1.00167224e6 units
#   Neighborhood 527: 191308.97 units
#   Neighborhood 529: 1.35352042e6 units
#   Neighborhood 549: 1.55877036e6 units
#   Neighborhood 560: 952747.6 units
#   Neighborhood 561: 1.97298076e6 units
#   Neighborhood 564: 1.08600505e6 units
#   Neighborhood 568: 71413.44 units
#   Neighborhood 577: 356661.87 units
#   Neighborhood 585: 37083.23 units
#
# Total neighborhoods receiving any food: 92
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 1.0, w_eq = 6.0 ===
# Total miles driven (transport cost, no penalty): 1.0081772e7
# Worst remaining deficit: 847789.09 units in neighborhood 33
# Total food given away: 7.508486888e7 units
#
# Neighborhoods that received food:
#
#   Neighborhood 4: 30374.2 units
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 336144.86 units
#   Neighborhood 50: 105498.51 units
#   Neighborhood 56: 131325.6 units
#   Neighborhood 69: 1.38360509e6 units
#   Neighborhood 93: 89959.74 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 129: 2.08411978e6 units
#   Neighborhood 140: 654463.32 units
#   Neighborhood 141: 1.21543539e6 units
#   Neighborhood 147: 272014.5 units
#   Neighborhood 156: 1.65488179e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 162: 361091.73 units
#   Neighborhood 163: 105866.87 units
#   Neighborhood 165: 1.3217667e6 units
#   Neighborhood 166: 975222.08 units
#   Neighborhood 168: 1.25106785e6 units
#   Neighborhood 172: 1.48120611e6 units
#   Neighborhood 174: 4495.47 units
#   Neighborhood 175: 137497.6 units
#   Neighborhood 179: 516452.32 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 183: 1.71372741e6 units
#   Neighborhood 191: 1.43565814e6 units
#   Neighborhood 195: 1.48225026e6 units
#   Neighborhood 196: 2.58943549e6 units
#   Neighborhood 203: 13128.31 units
#   Neighborhood 207: 1.61831304e6 units
#   Neighborhood 210: 318695.35 units
#   Neighborhood 211: 675834.13 units
#   Neighborhood 214: 31046.34 units
#   Neighborhood 242: 1.41541571e6 units
#   Neighborhood 245: 199350.9 units
#   Neighborhood 246: 529973.1 units
#   Neighborhood 247: 309582.17 units
#   Neighborhood 248: 2.33466528e6 units
#   Neighborhood 250: 3.43035965e6 units
#   Neighborhood 252: 728543.3 units
#   Neighborhood 254: 618305.66 units
#   Neighborhood 255: 1.18917588e6 units
#   Neighborhood 269: 130707.95 units
#   Neighborhood 313: 1.23241672e6 units
#   Neighborhood 319: 624041.39 units
#   Neighborhood 324: 3.54929376e6 units
#   Neighborhood 325: 129753.36 units
#   Neighborhood 326: 104606.61 units
#   Neighborhood 352: 2.58531201e6 units
#   Neighborhood 363: 1.15076209e6 units
#   Neighborhood 364: 2.77638771e6 units
#   Neighborhood 365: 77406.34 units
#   Neighborhood 366: 286424.67 units
#   Neighborhood 367: 2.0673391e6 units
#   Neighborhood 368: 451652.64 units
#   Neighborhood 371: 783122.06 units
#   Neighborhood 373: 444211.52 units
#   Neighborhood 380: 1.0536379e6 units
#   Neighborhood 400: 82217.31 units
#   Neighborhood 401: 225650.67 units
#   Neighborhood 402: 56685.28 units
#   Neighborhood 404: 323070.87 units
#   Neighborhood 439: 1.04176884e6 units
#   Neighborhood 445: 1.16682099e6 units
#   Neighborhood 447: 1.90235696e6 units
#   Neighborhood 449: 692540.13 units
#   Neighborhood 450: 35146.39 units
#   Neighborhood 451: 337974.46 units
#   Neighborhood 452: 889702.36 units
#   Neighborhood 474: 241155.88 units
#   Neighborhood 479: 196019.04 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 516: 180238.28 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 1.00167224e6 units
#   Neighborhood 527: 253537.26 units
#   Neighborhood 529: 1.41574871e6 units
#   Neighborhood 549: 1.62099865e6 units
#   Neighborhood 560: 1.01497589e6 units
#   Neighborhood 561: 2.03520905e6 units
#   Neighborhood 564: 1.14823334e6 units
#   Neighborhood 568: 133641.73 units
#   Neighborhood 577: 418890.16 units
#   Neighborhood 585: 37083.23 units
#
# Total neighborhoods receiving any food: 88
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 1.0, w_eq = 7.0 ===
# Total miles driven (transport cost, no penalty): 1.0328564e7
# Worst remaining deficit: 810974.15 units in neighborhood 255
# Total food given away: 7.508486888e7 units
#
# Neighborhoods that received food:
#
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 372959.8 units
#   Neighborhood 56: 168140.54 units
#   Neighborhood 69: 1.42042003e6 units
#   Neighborhood 93: 89959.74 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 129: 2.12093471e6 units
#   Neighborhood 140: 691278.26 units
#   Neighborhood 141: 1.25225033e6 units
#   Neighborhood 156: 1.69169673e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 162: 397906.67 units
#   Neighborhood 163: 105866.87 units
#   Neighborhood 165: 1.35858164e6 units
#   Neighborhood 166: 1.01203702e6 units
#   Neighborhood 168: 1.28788279e6 units
#   Neighborhood 172: 1.51802105e6 units
#   Neighborhood 174: 41310.41 units
#   Neighborhood 175: 174312.54 units
#   Neighborhood 179: 553267.26 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 183: 1.75054234e6 units
#   Neighborhood 191: 1.47247307e6 units
#   Neighborhood 195: 1.5190652e6 units
#   Neighborhood 196: 2.62625043e6 units
#   Neighborhood 203: 13128.31 units
#   Neighborhood 207: 1.65512798e6 units
#   Neighborhood 210: 355510.29 units
#   Neighborhood 211: 712649.07 units
#   Neighborhood 214: 67861.28 units
#   Neighborhood 242: 1.45223065e6 units
#   Neighborhood 245: 236165.84 units
#   Neighborhood 246: 566788.04 units
#   Neighborhood 247: 346397.11 units
#   Neighborhood 248: 2.37148022e6 units
#   Neighborhood 250: 3.46717459e6 units
#   Neighborhood 252: 765358.24 units
#   Neighborhood 254: 655120.6 units
#   Neighborhood 255: 1.22599082e6 units
#   Neighborhood 277: 88214.41 units
#   Neighborhood 313: 1.23241672e6 units
#   Neighborhood 319: 90542.77 units
#   Neighborhood 324: 3.54929376e6 units
#   Neighborhood 325: 129753.36 units
#   Neighborhood 352: 2.62212695e6 units
#   Neighborhood 363: 1.18757703e6 units
#   Neighborhood 364: 2.81320265e6 units
#   Neighborhood 365: 114221.28 units
#   Neighborhood 366: 323239.6 units
#   Neighborhood 367: 2.10415404e6 units
#   Neighborhood 368: 488467.58 units
#   Neighborhood 371: 819937.0 units
#   Neighborhood 372: 35896.49 units
#   Neighborhood 373: 481026.45 units
#   Neighborhood 380: 1.09045284e6 units
#   Neighborhood 400: 82217.31 units
#   Neighborhood 402: 93500.21 units
#   Neighborhood 404: 359885.81 units
#   Neighborhood 407: 5347.32 units
#   Neighborhood 439: 1.07858378e6 units
#   Neighborhood 445: 1.20363593e6 units
#   Neighborhood 447: 1.9391719e6 units
#   Neighborhood 449: 729355.07 units
#   Neighborhood 450: 71961.33 units
#   Neighborhood 451: 374789.4 units
#   Neighborhood 452: 926517.3 units
#   Neighborhood 474: 152941.46 units
#   Neighborhood 479: 196019.04 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 516: 180238.28 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 190698.09 units
#   Neighborhood 527: 290352.2 units
#   Neighborhood 529: 1.45256365e6 units
#   Neighborhood 549: 1.65781359e6 units
#   Neighborhood 560: 1.05179083e6 units
#   Neighborhood 561: 2.07202399e6 units
#   Neighborhood 564: 1.18504828e6 units
#   Neighborhood 568: 170456.67 units
#   Neighborhood 577: 455705.1 units
#   Neighborhood 585: 37083.23 units
#
# Total neighborhoods receiving any food: 85
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 1.0, w_eq = 8.0 ===
# Total miles driven (transport cost, no penalty): 1.043224e7
# Worst remaining deficit: 797194.91 units in neighborhood 33
# Total food given away: 7.508486888e7 units
#
# Neighborhoods that received food:
#
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 386739.04 units
#   Neighborhood 56: 181919.78 units
#   Neighborhood 69: 1.43419927e6 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 129: 2.13471396e6 units
#   Neighborhood 140: 705057.5 units
#   Neighborhood 141: 1.26602957e6 units
#   Neighborhood 156: 1.70547597e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 162: 411685.91 units
#   Neighborhood 163: 18365.92 units
#   Neighborhood 165: 1.37236088e6 units
#   Neighborhood 166: 1.02581626e6 units
#   Neighborhood 168: 1.30166203e6 units
#   Neighborhood 172: 1.53180029e6 units
#   Neighborhood 174: 55089.65 units
#   Neighborhood 175: 188091.78 units
#   Neighborhood 179: 567046.5 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 183: 1.76432159e6 units
#   Neighborhood 191: 1.48625232e6 units
#   Neighborhood 195: 1.53284444e6 units
#   Neighborhood 196: 2.64002967e6 units
#   Neighborhood 207: 1.66890722e6 units
#   Neighborhood 210: 369289.53 units
#   Neighborhood 211: 726428.31 units
#   Neighborhood 214: 81640.52 units
#   Neighborhood 242: 1.46600989e6 units
#   Neighborhood 245: 249945.08 units
#   Neighborhood 246: 580567.28 units
#   Neighborhood 247: 360176.35 units
#   Neighborhood 248: 2.38525946e6 units
#   Neighborhood 250: 3.48095383e6 units
#   Neighborhood 252: 779137.48 units
#   Neighborhood 254: 668899.84 units
#   Neighborhood 255: 1.23977006e6 units
#   Neighborhood 313: 1.23241672e6 units
#   Neighborhood 324: 3.54929376e6 units
#   Neighborhood 325: 129753.36 units
#   Neighborhood 352: 2.63590619e6 units
#   Neighborhood 363: 1.20135627e6 units
#   Neighborhood 364: 2.82698189e6 units
#   Neighborhood 365: 128000.52 units
#   Neighborhood 366: 337018.85 units
#   Neighborhood 367: 2.11793328e6 units
#   Neighborhood 368: 502246.82 units
#   Neighborhood 371: 833716.24 units
#   Neighborhood 372: 49675.73 units
#   Neighborhood 373: 494805.7 units
#   Neighborhood 380: 1.10423208e6 units
#   Neighborhood 402: 107279.46 units
#   Neighborhood 404: 373665.05 units
#   Neighborhood 407: 19126.56 units
#   Neighborhood 439: 1.09236302e6 units
#   Neighborhood 442: 13342.61 units
#   Neighborhood 445: 1.21741517e6 units
#   Neighborhood 447: 1.95295114e6 units
#   Neighborhood 449: 743134.31 units
#   Neighborhood 450: 85740.57 units
#   Neighborhood 451: 388568.64 units
#   Neighborhood 452: 940296.54 units
#   Neighborhood 479: 60921.4 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 516: 89268.61 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 204477.33 units
#   Neighborhood 527: 304131.44 units
#   Neighborhood 529: 1.46634289e6 units
#   Neighborhood 549: 1.67159283e6 units
#   Neighborhood 560: 1.06557007e6 units
#   Neighborhood 561: 2.08580323e6 units
#   Neighborhood 564: 1.19882752e6 units
#   Neighborhood 568: 184235.91 units
#   Neighborhood 577: 469484.34 units
#
# Total neighborhoods receiving any food: 79
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 1.0, w_eq = 9.0 ===
# Total miles driven (transport cost, no penalty): 1.045395e7
# Worst remaining deficit: 794577.23 units in neighborhood 129
# Total food given away: 7.508486888e7 units
#
# Neighborhoods that received food:
#
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 389356.72 units
#   Neighborhood 56: 184537.46 units
#   Neighborhood 69: 1.43681695e6 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 129: 2.13733164e6 units
#   Neighborhood 140: 707675.18 units
#   Neighborhood 141: 1.26864725e6 units
#   Neighborhood 149: 1024.37 units
#   Neighborhood 156: 1.70809365e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 162: 414303.59 units
#   Neighborhood 165: 1.37497856e6 units
#   Neighborhood 166: 1.02843394e6 units
#   Neighborhood 168: 1.30427971e6 units
#   Neighborhood 172: 1.53441797e6 units
#   Neighborhood 174: 57707.33 units
#   Neighborhood 175: 190709.46 units
#   Neighborhood 179: 569664.18 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 183: 1.76693927e6 units
#   Neighborhood 191: 1.48887e6 units
#   Neighborhood 195: 1.53546212e6 units
#   Neighborhood 196: 2.64264735e6 units
#   Neighborhood 197: 2617.68 units
#   Neighborhood 207: 1.6715249e6 units
#   Neighborhood 210: 371907.21 units
#   Neighborhood 211: 729045.99 units
#   Neighborhood 214: 84258.2 units
#   Neighborhood 242: 1.46862757e6 units
#   Neighborhood 245: 252562.76 units
#   Neighborhood 246: 583184.96 units
#   Neighborhood 247: 362794.03 units
#   Neighborhood 248: 2.38787714e6 units
#   Neighborhood 250: 3.48357151e6 units
#   Neighborhood 252: 781755.16 units
#   Neighborhood 254: 671517.52 units
#   Neighborhood 255: 1.24238774e6 units
#   Neighborhood 313: 1.23241672e6 units
#   Neighborhood 324: 3.54929376e6 units
#   Neighborhood 325: 129753.36 units
#   Neighborhood 352: 2.63852387e6 units
#   Neighborhood 363: 1.20397395e6 units
#   Neighborhood 364: 2.82959957e6 units
#   Neighborhood 365: 130618.2 units
#   Neighborhood 366: 339636.53 units
#   Neighborhood 367: 2.12055096e6 units
#   Neighborhood 368: 504864.5 units
#   Neighborhood 371: 836333.92 units
#   Neighborhood 372: 52293.41 units
#   Neighborhood 373: 497423.38 units
#   Neighborhood 380: 1.10684976e6 units
#   Neighborhood 402: 109897.14 units
#   Neighborhood 404: 376282.73 units
#   Neighborhood 407: 21744.24 units
#   Neighborhood 439: 1.0949807e6 units
#   Neighborhood 442: 15960.29 units
#   Neighborhood 445: 1.22003285e6 units
#   Neighborhood 447: 1.95556882e6 units
#   Neighborhood 449: 745751.99 units
#   Neighborhood 450: 88358.25 units
#   Neighborhood 451: 391186.32 units
#   Neighborhood 452: 942914.22 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 207095.01 units
#   Neighborhood 527: 306749.12 units
#   Neighborhood 529: 1.46896057e6 units
#   Neighborhood 549: 1.67421051e6 units
#   Neighborhood 560: 1.06818775e6 units
#   Neighborhood 561: 2.08842091e6 units
#   Neighborhood 564: 1.2014452e6 units
#   Neighborhood 568: 186853.59 units
#   Neighborhood 577: 472102.02 units
#
# Total neighborhoods receiving any food: 78
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 1.0, w_eq = 10.0 ===
# Total miles driven (transport cost, no penalty): 1.1048218e7
# Worst remaining deficit: 731641.08 units in neighborhood 129
# Total food given away: 7.508486888e7 units
#
# Neighborhoods that received food:
#
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 452292.86 units
#   Neighborhood 56: 247473.61 units
#   Neighborhood 69: 1.49975309e6 units
#   Neighborhood 129: 2.20026778e6 units
#   Neighborhood 140: 770611.32 units
#   Neighborhood 141: 1.33158339e6 units
#   Neighborhood 149: 63960.51 units
#   Neighborhood 156: 1.7710298e6 units
#   Neighborhood 162: 477239.74 units
#   Neighborhood 165: 1.4379147e6 units
#   Neighborhood 166: 1.09137008e6 units
#   Neighborhood 168: 1.36721585e6 units
#   Neighborhood 172: 1.59735412e6 units
#   Neighborhood 174: 120643.48 units
#   Neighborhood 175: 253645.6 units
#   Neighborhood 179: 632600.33 units
#   Neighborhood 182: 2.54108399e6 units
#   Neighborhood 183: 1.82987541e6 units
#   Neighborhood 191: 1.55180614e6 units
#   Neighborhood 195: 1.59839826e6 units
#   Neighborhood 196: 2.7055835e6 units
#   Neighborhood 197: 65553.83 units
#   Neighborhood 207: 1.73446105e6 units
#   Neighborhood 210: 434843.35 units
#   Neighborhood 211: 791982.14 units
#   Neighborhood 214: 147194.35 units
#   Neighborhood 242: 1.53156371e6 units
#   Neighborhood 244: 6152.79 units
#   Neighborhood 245: 315498.9 units
#   Neighborhood 246: 646121.11 units
#   Neighborhood 247: 425730.18 units
#   Neighborhood 248: 2.45081329e6 units
#   Neighborhood 250: 3.54650766e6 units
#   Neighborhood 252: 844691.3 units
#   Neighborhood 254: 734453.67 units
#   Neighborhood 255: 1.30532389e6 units
#   Neighborhood 313: 521045.1 units
#   Neighborhood 324: 2.81765268e6 units
#   Neighborhood 352: 2.70146002e6 units
#   Neighborhood 363: 1.26691009e6 units
#   Neighborhood 364: 2.89253571e6 units
#   Neighborhood 365: 193554.35 units
#   Neighborhood 366: 402572.67 units
#   Neighborhood 367: 2.1834871e6 units
#   Neighborhood 368: 567800.64 units
#   Neighborhood 371: 899270.07 units
#   Neighborhood 372: 115229.55 units
#   Neighborhood 373: 560359.52 units
#   Neighborhood 380: 1.1697859e6 units
#   Neighborhood 402: 172833.28 units
#   Neighborhood 404: 439218.88 units
#   Neighborhood 407: 84680.39 units
#   Neighborhood 439: 1.15791685e6 units
#   Neighborhood 442: 78896.44 units
#   Neighborhood 445: 1.282969e6 units
#   Neighborhood 447: 2.01850496e6 units
#   Neighborhood 449: 808688.14 units
#   Neighborhood 450: 151294.4 units
#   Neighborhood 451: 454122.47 units
#   Neighborhood 452: 1.00585036e6 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 92298.87 units
#   Neighborhood 521: 661040.71 units
#   Neighborhood 523: 270031.16 units
#   Neighborhood 527: 369685.26 units
#   Neighborhood 529: 1.53189672e6 units
#   Neighborhood 549: 1.73714665e6 units
#   Neighborhood 560: 1.1311239e6 units
#   Neighborhood 561: 2.15135705e6 units
#   Neighborhood 564: 1.26438135e6 units
#   Neighborhood 568: 249789.74 units
#   Neighborhood 577: 535038.16 units
#
# Total neighborhoods receiving any food: 75
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 10.0, w_eq = 1.0 ===
# Total miles driven (transport cost, no penalty): 6.934084e6
# Worst remaining deficit: 2.91512819e6 units in neighborhood 129
# Total food given away: 7.508486888e7 units
#
# Neighborhoods that received food:
#
#   Neighborhood 1: 102142.62 units
#   Neighborhood 2: 333492.65 units
#   Neighborhood 4: 113652.81 units
#   Neighborhood 8: 113911.46 units
#   Neighborhood 20: 23547.32 units
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 1.18393395e6 units
#   Neighborhood 40: 40369.71 units
#   Neighborhood 50: 105498.51 units
#   Neighborhood 56: 979114.69 units
#   Neighborhood 59: 23285.42 units
#   Neighborhood 80: 238489.99 units
#   Neighborhood 93: 89959.74 units
#   Neighborhood 101: 704873.88 units
#   Neighborhood 111: 258687.53 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 115: 175960.45 units
#   Neighborhood 118: 261754.51 units
#   Neighborhood 120: 405519.22 units
#   Neighborhood 124: 2162.6 units
#   Neighborhood 129: 16780.68 units
#   Neighborhood 135: 363136.01 units
#   Neighborhood 140: 141381.06 units
#   Neighborhood 147: 272014.5 units
#   Neighborhood 155: 720808.95 units
#   Neighborhood 156: 2.50267088e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 163: 105866.87 units
#   Neighborhood 166: 177171.69 units
#   Neighborhood 168: 2.09885694e6 units
#   Neighborhood 172: 754852.26 units
#   Neighborhood 173: 25318.04 units
#   Neighborhood 174: 304986.03 units
#   Neighborhood 175: 985286.69 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 191: 2.28344722e6 units
#   Neighborhood 194: 311007.77 units
#   Neighborhood 195: 246155.18 units
#   Neighborhood 196: 522096.39 units
#   Neighborhood 197: 797194.91 units
#   Neighborhood 203: 13128.31 units
#   Neighborhood 207: 2.46610213e6 units
#   Neighborhood 209: 373365.51 units
#   Neighborhood 214: 123843.42 units
#   Neighborhood 221: 404200.91 units
#   Neighborhood 222: 56409.56 units
#   Neighborhood 223: 560298.34 units
#   Neighborhood 233: 474243.0 units
#   Neighborhood 236: 424811.03 units
#   Neighborhood 237: 509307.12 units
#   Neighborhood 242: 2.2632048e6 units
#   Neighborhood 244: 737793.87 units
#   Neighborhood 245: 1.04713999e6 units
#   Neighborhood 246: 1.37776219e6 units
#   Neighborhood 247: 1.15737126e6 units
#   Neighborhood 248: 267326.19 units
#   Neighborhood 250: 1.36302055e6 units
#   Neighborhood 252: 1.57633239e6 units
#   Neighborhood 253: 690257.6 units
#   Neighborhood 254: 1.46609475e6 units
#   Neighborhood 255: 2.03696497e6 units
#   Neighborhood 269: 130707.95 units
#   Neighborhood 277: 88214.41 units
#   Neighborhood 313: 1.23241672e6 units
#   Neighborhood 319: 624041.39 units
#   Neighborhood 324: 3.54929376e6 units
#   Neighborhood 325: 129753.36 units
#   Neighborhood 326: 104606.61 units
#   Neighborhood 327: 557994.27 units
#   Neighborhood 336: 481957.93 units
#   Neighborhood 346: 311932.67 units
#   Neighborhood 352: 517972.91 units
#   Neighborhood 355: 196114.86 units
#   Neighborhood 364: 709048.61 units
#   Neighborhood 371: 317865.15 units
#   Neighborhood 379: 237746.9 units
#   Neighborhood 380: 1.90142699e6 units
#   Neighborhood 381: 124780.28 units
#   Neighborhood 384: 722445.96 units
#   Neighborhood 400: 82217.31 units
#   Neighborhood 401: 225650.67 units
#   Neighborhood 402: 904474.36 units
#   Neighborhood 404: 1.17085996e6 units
#   Neighborhood 417: 255191.16 units
#   Neighborhood 434: 77079.76 units
#   Neighborhood 439: 1.88955793e6 units
#   Neighborhood 441: 156023.38 units
#   Neighborhood 442: 810537.52 units
#   Neighborhood 443: 575068.83 units
#   Neighborhood 444: 319917.59 units
#   Neighborhood 449: 1.54032922e6 units
#   Neighborhood 450: 882935.48 units
#   Neighborhood 451: 1.18576355e6 units
#   Neighborhood 452: 1.73749145e6 units
#   Neighborhood 474: 478056.68 units
#   Neighborhood 479: 196019.04 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 516: 180238.28 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 1.00167224e6 units
#   Neighborhood 526: 164804.51 units
#   Neighborhood 527: 1.10132634e6 units
#   Neighborhood 529: 2.2635378e6 units
#   Neighborhood 532: 209126.85 units
#   Neighborhood 533: 527148.97 units
#   Neighborhood 543: 309269.1 units
#   Neighborhood 552: 121379.77 units
#   Neighborhood 577: 876825.15 units
#   Neighborhood 581: 252089.29 units
#   Neighborhood 585: 37083.23 units
#
# Total neighborhoods receiving any food: 114
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 9.0, w_eq = 1.0 ===
# Total miles driven (transport cost, no penalty): 6.935772e6
# Worst remaining deficit: 2.89864768e6 units in neighborhood 129
# Total food given away: 7.508486888e7 units
#
# Neighborhoods that received food:
#
#   Neighborhood 1: 102142.62 units
#   Neighborhood 2: 333492.65 units
#   Neighborhood 4: 113652.81 units
#   Neighborhood 8: 113911.46 units
#   Neighborhood 20: 23547.32 units
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 1.18393395e6 units
#   Neighborhood 40: 40369.71 units
#   Neighborhood 50: 105498.51 units
#   Neighborhood 56: 979114.69 units
#   Neighborhood 59: 23285.42 units
#   Neighborhood 69: 123843.42 units
#   Neighborhood 80: 238489.99 units
#   Neighborhood 93: 89959.74 units
#   Neighborhood 101: 704873.88 units
#   Neighborhood 111: 258687.53 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 115: 175960.45 units
#   Neighborhood 118: 261754.51 units
#   Neighborhood 120: 405519.22 units
#   Neighborhood 124: 2162.6 units
#   Neighborhood 129: 33261.18 units
#   Neighborhood 135: 363136.01 units
#   Neighborhood 147: 272014.5 units
#   Neighborhood 155: 262908.45 units
#   Neighborhood 156: 2.50267088e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 163: 105866.87 units
#   Neighborhood 166: 979333.9 units
#   Neighborhood 168: 2.09885694e6 units
#   Neighborhood 172: 662504.44 units
#   Neighborhood 174: 367092.66 units
#   Neighborhood 175: 985286.69 units
#   Neighborhood 179: 268423.63 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 191: 2.28344722e6 units
#   Neighborhood 194: 311007.77 units
#   Neighborhood 195: 229674.67 units
#   Neighborhood 196: 538576.9 units
#   Neighborhood 197: 797194.91 units
#   Neighborhood 203: 13128.31 units
#   Neighborhood 207: 2.46610213e6 units
#   Neighborhood 209: 373365.51 units
#   Neighborhood 221: 404200.91 units
#   Neighborhood 222: 56409.56 units
#   Neighborhood 223: 560298.34 units
#   Neighborhood 236: 424811.03 units
#   Neighborhood 237: 509307.12 units
#   Neighborhood 242: 2.2632048e6 units
#   Neighborhood 244: 737793.87 units
#   Neighborhood 245: 1.04713999e6 units
#   Neighborhood 246: 1.37776219e6 units
#   Neighborhood 247: 1.15737126e6 units
#   Neighborhood 248: 283806.69 units
#   Neighborhood 250: 1.37950106e6 units
#   Neighborhood 252: 1.57633239e6 units
#   Neighborhood 253: 690257.6 units
#   Neighborhood 254: 1.46609475e6 units
#   Neighborhood 255: 2.03696497e6 units
#   Neighborhood 269: 130707.95 units
#   Neighborhood 277: 88214.41 units
#   Neighborhood 313: 1.23241672e6 units
#   Neighborhood 319: 624041.39 units
#   Neighborhood 324: 3.54929376e6 units
#   Neighborhood 325: 129753.36 units
#   Neighborhood 326: 104606.61 units
#   Neighborhood 327: 557994.27 units
#   Neighborhood 336: 481957.93 units
#   Neighborhood 346: 311932.67 units
#   Neighborhood 352: 610320.74 units
#   Neighborhood 355: 196114.86 units
#   Neighborhood 364: 725529.12 units
#   Neighborhood 367: 16480.51 units
#   Neighborhood 379: 237746.9 units
#   Neighborhood 380: 1.90142699e6 units
#   Neighborhood 381: 124780.28 units
#   Neighborhood 384: 722445.96 units
#   Neighborhood 400: 82217.31 units
#   Neighborhood 401: 225650.67 units
#   Neighborhood 402: 904474.36 units
#   Neighborhood 404: 1.17085996e6 units
#   Neighborhood 407: 108420.05 units
#   Neighborhood 417: 255191.16 units
#   Neighborhood 430: 412136.38 units
#   Neighborhood 434: 77079.76 units
#   Neighborhood 439: 1.88955793e6 units
#   Neighborhood 441: 156023.38 units
#   Neighborhood 442: 810537.52 units
#   Neighborhood 443: 575068.83 units
#   Neighborhood 444: 319917.59 units
#   Neighborhood 449: 1.54032922e6 units
#   Neighborhood 450: 882935.48 units
#   Neighborhood 451: 1.18576355e6 units
#   Neighborhood 452: 1.73749145e6 units
#   Neighborhood 474: 478056.68 units
#   Neighborhood 479: 196019.04 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 516: 180238.28 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 1.00167224e6 units
#   Neighborhood 526: 164804.51 units
#   Neighborhood 527: 1.10132634e6 units
#   Neighborhood 529: 2.2635378e6 units
#   Neighborhood 532: 209126.85 units
#   Neighborhood 533: 527148.97 units
#   Neighborhood 543: 309269.1 units
#   Neighborhood 551: 25318.04 units
#   Neighborhood 552: 121379.77 units
#   Neighborhood 577: 74662.94 units
#   Neighborhood 581: 709989.79 units
#   Neighborhood 585: 37083.23 units
#
# Total neighborhoods receiving any food: 115
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 8.0, w_eq = 1.0 ===
# Total miles driven (transport cost, no penalty): 6.93577e6
# Worst remaining deficit: 2.89864768e6 units in neighborhood 129
# Total food given away: 7.508486888e7 units
#
# Neighborhoods that received food:
#
#   Neighborhood 1: 102142.62 units
#   Neighborhood 2: 333492.65 units
#   Neighborhood 4: 113652.81 units
#   Neighborhood 8: 113911.46 units
#   Neighborhood 20: 23547.32 units
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 1.18393395e6 units
#   Neighborhood 40: 40369.71 units
#   Neighborhood 50: 105498.51 units
#   Neighborhood 56: 979114.69 units
#   Neighborhood 59: 23285.42 units
#   Neighborhood 69: 123843.42 units
#   Neighborhood 80: 238489.99 units
#   Neighborhood 93: 89959.74 units
#   Neighborhood 101: 704873.88 units
#   Neighborhood 111: 258687.53 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 115: 175960.45 units
#   Neighborhood 118: 261754.51 units
#   Neighborhood 120: 405519.22 units
#   Neighborhood 124: 2162.6 units
#   Neighborhood 129: 33261.18 units
#   Neighborhood 135: 363136.01 units
#   Neighborhood 147: 272014.5 units
#   Neighborhood 155: 720808.95 units
#   Neighborhood 156: 2.50267088e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 163: 105866.87 units
#   Neighborhood 168: 2.09885694e6 units
#   Neighborhood 172: 738371.75 units
#   Neighborhood 174: 304986.03 units
#   Neighborhood 175: 985286.69 units
#   Neighborhood 179: 268423.63 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 191: 2.28344722e6 units
#   Neighborhood 194: 311007.77 units
#   Neighborhood 196: 538576.9 units
#   Neighborhood 197: 797194.91 units
#   Neighborhood 203: 13128.31 units
#   Neighborhood 207: 2.46610213e6 units
#   Neighborhood 209: 373365.51 units
#   Neighborhood 221: 404200.91 units
#   Neighborhood 222: 56409.56 units
#   Neighborhood 223: 560298.34 units
#   Neighborhood 233: 474243.0 units
#   Neighborhood 236: 424811.03 units
# ...
#   Neighborhood 479: 196019.04 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 516: 180238.28 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 1.00167224e6 units
#   Neighborhood 526: 164804.51 units
#   Neighborhood 527: 1.10132634e6 units
#   Neighborhood 529: 2.2635378e6 units
#   Neighborhood 532: 209126.85 units
#   Neighborhood 533: 527148.97 units
#   Neighborhood 543: 309269.1 units
#   Neighborhood 552: 121379.77 units
#   Neighborhood 561: 107718.21 units
#   Neighborhood 581: 252089.29 units
#   Neighborhood 585: 37083.23 units
#
# Total neighborhoods receiving any food: 110
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 4.0, w_eq = 1.0 ===
# Total miles driven (transport cost, no penalty): 6.981514e6
# Worst remaining deficit: 2.66897301e6 units in neighborhood 129
# Total food given away: 7.508486888e7 units
#
# Neighborhoods that received food:
#
#   Neighborhood 1: 102142.62 units
#   Neighborhood 2: 333492.65 units
#   Neighborhood 4: 113652.81 units
#   Neighborhood 8: 113911.46 units
#   Neighborhood 20: 23547.32 units
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 1.18393395e6 units
#   Neighborhood 40: 40369.71 units
#   Neighborhood 50: 105498.51 units
#   Neighborhood 56: 979114.69 units
#   Neighborhood 59: 23285.42 units
#   Neighborhood 80: 238489.99 units
#   Neighborhood 93: 89959.74 units
#   Neighborhood 101: 704873.88 units
#   Neighborhood 111: 258687.53 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 115: 175960.45 units
#   Neighborhood 118: 261754.51 units
#   Neighborhood 120: 405519.22 units
#   Neighborhood 124: 2162.6 units
#   Neighborhood 129: 262935.86 units
#   Neighborhood 135: 363136.01 units
#   Neighborhood 147: 272014.5 units
#   Neighborhood 155: 720808.95 units
#   Neighborhood 156: 2.50267088e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 163: 105866.87 units
#   Neighborhood 166: 1.82301116e6 units
#   Neighborhood 168: 2.09885694e6 units
#   Neighborhood 174: 91166.72 units
#   Neighborhood 175: 985286.69 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 191: 2.28344722e6 units
#   Neighborhood 194: 311007.77 units
#   Neighborhood 196: 768251.57 units
#   Neighborhood 197: 797194.91 units
#   Neighborhood 203: 13128.31 units
#   Neighborhood 207: 2.46610213e6 units
#   Neighborhood 209: 373365.51 units
#   Neighborhood 221: 404200.91 units
#   Neighborhood 222: 56409.56 units
#   Neighborhood 223: 560298.34 units
#   Neighborhood 233: 275925.93 units
#   Neighborhood 236: 424811.03 units
#   Neighborhood 237: 509307.12 units
#   Neighborhood 242: 2.2632048e6 units
#   Neighborhood 244: 737793.87 units
#   Neighborhood 245: 1.04713999e6 units
#   Neighborhood 246: 1.37776219e6 units
#   Neighborhood 247: 1.15737126e6 units
#   Neighborhood 248: 513481.37 units
#   Neighborhood 250: 1.60917574e6 units
#   Neighborhood 252: 1.57633239e6 units
#   Neighborhood 253: 690257.6 units
#   Neighborhood 254: 1.46609475e6 units
#   Neighborhood 255: 2.03696497e6 units
#   Neighborhood 269: 130707.95 units
#   Neighborhood 277: 88214.41 units
#   Neighborhood 313: 1.23241672e6 units
#   Neighborhood 319: 624041.39 units
#   Neighborhood 324: 3.54929376e6 units
#   Neighborhood 325: 129753.36 units
#   Neighborhood 326: 104606.61 units
#   Neighborhood 327: 557994.27 units
#   Neighborhood 336: 481957.93 units
#   Neighborhood 346: 311932.67 units
#   Neighborhood 352: 764128.09 units
#   Neighborhood 355: 196114.86 units
#   Neighborhood 364: 955203.79 units
#   Neighborhood 367: 246155.18 units
#   Neighborhood 379: 237746.9 units
#   Neighborhood 380: 66997.76 units
#   Neighborhood 381: 124780.28 units
#   Neighborhood 384: 722445.96 units
#   Neighborhood 400: 82217.31 units
#   Neighborhood 401: 225650.67 units
#   Neighborhood 402: 904474.36 units
#   Neighborhood 404: 1.17085996e6 units
#   Neighborhood 417: 255191.16 units
#   Neighborhood 430: 412136.38 units
#   Neighborhood 434: 77079.76 units
#   Neighborhood 439: 1.88955793e6 units
#   Neighborhood 441: 156023.38 units
#   Neighborhood 442: 810537.52 units
#   Neighborhood 443: 575068.83 units
#   Neighborhood 444: 319917.59 units
#   Neighborhood 447: 81173.04 units
#   Neighborhood 449: 1.54032922e6 units
#   Neighborhood 450: 882935.48 units
#   Neighborhood 451: 1.18576355e6 units
#   Neighborhood 452: 1.73749145e6 units
#   Neighborhood 474: 478056.68 units
#   Neighborhood 479: 196019.04 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 516: 180238.28 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 1.00167224e6 units
#   Neighborhood 526: 164804.51 units
#   Neighborhood 527: 1.10132634e6 units
#   Neighborhood 529: 2.2635378e6 units
#   Neighborhood 532: 209126.85 units
#   Neighborhood 533: 527148.97 units
#   Neighborhood 543: 309269.1 units
#   Neighborhood 549: 70347.64 units
#   Neighborhood 552: 121379.77 units
#   Neighborhood 561: 214025.13 units
#   Neighborhood 577: 586197.94 units
#   Neighborhood 581: 252089.29 units
#   Neighborhood 585: 37083.23 units
#
# Total neighborhoods receiving any food: 113
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 3.0, w_eq = 1.0 ===
# Total miles driven (transport cost, no penalty): 6.994308e6
# Worst remaining deficit: 2.62505191e6 units in neighborhood 129
# Total food given away: 7.508486888e7 units
#
# Neighborhoods that received food:
#
#   Neighborhood 1: 102142.62 units
#   Neighborhood 2: 333492.65 units
#   Neighborhood 4: 113652.81 units
#   Neighborhood 8: 113911.46 units
#   Neighborhood 20: 23547.32 units
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 1.18393395e6 units
#   Neighborhood 40: 40369.71 units
#   Neighborhood 50: 105498.51 units
#   Neighborhood 56: 979114.69 units
#   Neighborhood 59: 23285.42 units
#   Neighborhood 80: 238489.99 units
#   Neighborhood 93: 89959.74 units
#   Neighborhood 101: 704873.88 units
#   Neighborhood 111: 258687.53 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 115: 175960.45 units
#   Neighborhood 118: 261754.51 units
#   Neighborhood 120: 405519.22 units
#   Neighborhood 124: 2162.6 units
#   Neighborhood 129: 306856.96 units
#   Neighborhood 135: 363136.01 units
#   Neighborhood 147: 272014.5 units
#   Neighborhood 155: 720808.95 units
#   Neighborhood 156: 2.50267088e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 163: 105866.87 units
#   Neighborhood 166: 884585.36 units
#   Neighborhood 168: 2.09885694e6 units
#   Neighborhood 175: 985286.69 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 191: 2.28344722e6 units
#   Neighborhood 194: 311007.77 units
#   Neighborhood 196: 812172.67 units
#   Neighborhood 197: 797194.91 units
#   Neighborhood 203: 13128.31 units
#   Neighborhood 207: 2.46610213e6 units
#   Neighborhood 209: 373365.51 units
#   Neighborhood 221: 404200.91 units
#   Neighborhood 222: 56409.56 units
#   Neighborhood 223: 560298.34 units
#   Neighborhood 233: 474243.0 units
#   Neighborhood 236: 424811.03 units
#   Neighborhood 237: 509307.12 units
#   Neighborhood 242: 2.2632048e6 units
#   Neighborhood 244: 737793.87 units
#   Neighborhood 245: 1.04713999e6 units
#   Neighborhood 246: 1.37776219e6 units
#   Neighborhood 247: 1.15737126e6 units
#   Neighborhood 248: 557402.47 units
#   Neighborhood 250: 1.65309683e6 units
#   Neighborhood 252: 1.57633239e6 units
#   Neighborhood 253: 690257.6 units
#   Neighborhood 254: 1.46609475e6 units
#   Neighborhood 255: 2.03696497e6 units
#   Neighborhood 269: 130707.95 units
#   Neighborhood 277: 88214.41 units
#   Neighborhood 313: 1.23241672e6 units
#   Neighborhood 319: 624041.39 units
#   Neighborhood 324: 3.54929376e6 units
#   Neighborhood 325: 129753.36 units
#   Neighborhood 326: 104606.61 units
#   Neighborhood 327: 557994.27 units
#   Neighborhood 336: 481957.93 units
#   Neighborhood 346: 311932.67 units
#   Neighborhood 352: 808049.19 units
#   Neighborhood 355: 196114.86 units
#   Neighborhood 364: 999124.89 units
#   Neighborhood 367: 290076.28 units
#   Neighborhood 379: 237746.9 units
#   Neighborhood 381: 124780.28 units
#   Neighborhood 384: 722445.96 units
#   Neighborhood 400: 82217.31 units
#   Neighborhood 401: 225650.67 units
#   Neighborhood 402: 904474.36 units
#   Neighborhood 404: 1.17085996e6 units
#   Neighborhood 417: 255191.16 units
#   Neighborhood 430: 304986.03 units
#   Neighborhood 434: 77079.76 units
#   Neighborhood 439: 1.88955793e6 units
#   Neighborhood 441: 156023.38 units
#   Neighborhood 442: 810537.52 units
#   Neighborhood 443: 575068.83 units
#   Neighborhood 444: 319917.59 units
#   Neighborhood 447: 125094.14 units
#   Neighborhood 449: 1.54032922e6 units
#   Neighborhood 450: 882935.48 units
#   Neighborhood 451: 1.18576355e6 units
#   Neighborhood 452: 1.73749145e6 units
#   Neighborhood 474: 478056.68 units
#   Neighborhood 479: 196019.04 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 516: 180238.28 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 1.00167224e6 units
#   Neighborhood 526: 164804.51 units
#   Neighborhood 527: 1.10132634e6 units
#   Neighborhood 529: 2.2635378e6 units
#   Neighborhood 532: 209126.85 units
#   Neighborhood 533: 527148.97 units
#   Neighborhood 543: 309269.1 units
#   Neighborhood 552: 121379.77 units
#   Neighborhood 561: 257946.23 units
#   Neighborhood 577: 1.26667925e6 units
#   Neighborhood 581: 252089.29 units
#   Neighborhood 585: 37083.23 units
#
# Total neighborhoods receiving any food: 110
#
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
#
# === Weights: w_cost = 2.0, w_eq = 1.0 ===
# Total miles driven (transport cost, no penalty): 7.112076e6
# Worst remaining deficit: 2.35296154e6 units in neighborhood 129
# Total food given away: 7.508486888e7 units
#
# Neighborhoods that received food:
#
#   Neighborhood 1: 102142.62 units
#   Neighborhood 2: 333492.65 units
#   Neighborhood 4: 113652.81 units
#   Neighborhood 8: 113911.46 units
#   Neighborhood 20: 23547.32 units
#   Neighborhood 28: 267239.25 units
#   Neighborhood 33: 1.18393395e6 units
#   Neighborhood 40: 40369.71 units
#   Neighborhood 50: 105498.51 units
#   Neighborhood 56: 979114.69 units
#   Neighborhood 59: 23285.42 units
#   Neighborhood 80: 238489.99 units
#   Neighborhood 93: 89959.74 units
#   Neighborhood 101: 704873.88 units
#   Neighborhood 111: 258687.53 units
#   Neighborhood 114: 16549.04 units
#   Neighborhood 118: 261754.51 units
#   Neighborhood 120: 405519.22 units
#   Neighborhood 129: 578947.32 units
#   Neighborhood 135: 363136.01 units
#   Neighborhood 147: 272014.5 units
#   Neighborhood 155: 720808.95 units
#   Neighborhood 156: 2.50267088e6 units
#   Neighborhood 158: 605451.43 units
#   Neighborhood 163: 105866.87 units
#   Neighborhood 166: 534553.88 units
#   Neighborhood 168: 2.09885694e6 units
#   Neighborhood 174: 631731.51 units
#   Neighborhood 175: 985286.69 units
#   Neighborhood 182: 3.27272507e6 units
#   Neighborhood 183: 208554.95 units
#   Neighborhood 191: 2.28344722e6 units
#   Neighborhood 194: 311007.77 units
#   Neighborhood 196: 1.08426304e6 units
#   Neighborhood 197: 797194.91 units
#   Neighborhood 203: 13128.31 units
#   Neighborhood 207: 2.46610213e6 units
#   Neighborhood 209: 373365.51 units
#   Neighborhood 221: 404200.91 units
#   Neighborhood 222: 56409.56 units
#   Neighborhood 223: 560298.34 units
#   Neighborhood 236: 424811.03 units
#   Neighborhood 237: 509307.12 units
#   Neighborhood 242: 2.2632048e6 units
#   Neighborhood 244: 737793.87 units
#   Neighborhood 245: 1.04713999e6 units
#   Neighborhood 246: 1.37776219e6 units
#   Neighborhood 247: 363026.95 units
#   Neighborhood 248: 829492.83 units
#   Neighborhood 250: 1.9251872e6 units
#   Neighborhood 252: 1.57633239e6 units
#   Neighborhood 253: 690257.6 units
#   Neighborhood 254: 1.46609475e6 units
#   Neighborhood 255: 2.03696497e6 units
#   Neighborhood 269: 130707.95 units
#   Neighborhood 277: 88214.41 units
#   Neighborhood 313: 1.23241672e6 units
#   Neighborhood 319: 624041.39 units
#   Neighborhood 324: 3.54929376e6 units
#   Neighborhood 325: 129753.36 units
#   Neighborhood 326: 104606.61 units
#   Neighborhood 327: 557994.27 units
#   Neighborhood 336: 481957.93 units
#   Neighborhood 352: 1.08013956e6 units
#   Neighborhood 364: 1.27121526e6 units
#   Neighborhood 367: 562166.65 units
#   Neighborhood 379: 237746.9 units
#   Neighborhood 380: 893773.78 units
#   Neighborhood 381: 124780.28 units
#   Neighborhood 384: 722445.96 units
#   Neighborhood 400: 82217.31 units
#   Neighborhood 401: 225650.67 units
#   Neighborhood 402: 904474.36 units
#   Neighborhood 404: 1.17085996e6 units
#   Neighborhood 417: 255191.16 units
#   Neighborhood 434: 77079.76 units
#   Neighborhood 439: 1.88955793e6 units
#   Neighborhood 441: 156023.38 units
#   Neighborhood 442: 810537.52 units
#   Neighborhood 443: 575068.83 units
#   Neighborhood 444: 279347.42 units
#   Neighborhood 447: 397184.51 units
#   Neighborhood 449: 1.54032922e6 units
#   Neighborhood 450: 882935.48 units
#   Neighborhood 451: 1.18576355e6 units
#   Neighborhood 452: 1.73749145e6 units
#   Neighborhood 474: 478056.68 units
#   Neighborhood 479: 196019.04 units
#   Neighborhood 493: 311334.06 units
#   Neighborhood 496: 34734.24 units
#   Neighborhood 507: 8538.37 units
#   Neighborhood 510: 441461.4 units
#   Neighborhood 516: 180238.28 units
#   Neighborhood 521: 1.39268179e6 units
#   Neighborhood 522: 89791.06 units
#   Neighborhood 523: 1.00167224e6 units
#   Neighborhood 526: 164804.51 units
#   Neighborhood 527: 1.10132634e6 units
#   Neighborhood 529: 2.2635378e6 units
#   Neighborhood 532: 209126.85 units
#   Neighborhood 533: 527148.97 units
#   Neighborhood 549: 115826.2 units
#   Neighborhood 561: 530036.6 units
#   Neighborhood 577: 48973.94 units
#   Neighborhood 581: 252089.29 units
#   Neighborhood 585: 37083.23 units
#
# Total neighborhoods receiving any food: 106
#
# === Summary table over all weights ===
# 19×7 DataFrame
#  Row │ w_cost   w_eq     obj_value   cost_value  equity_t        total_recv  total_unmet
#      │ Float64  Float64  Float64     Float64     Float64         Float64     Float64
# ─────┼───────────────────────────────────────────────────────────────────────────────────
#    1 │     1.0      1.0  1.17919e16  1.17919e16       2.01461e6   7.50849e7    7.73545e7
#    2 │     1.0      2.0  1.17919e16  1.17919e16       1.34038e6   7.50849e7    7.73545e7
#    3 │     1.0      3.0  1.17919e16  1.17919e16       1.13421e6   7.50849e7    7.73545e7
#    4 │     1.0      4.0  1.17919e16  1.17919e16  974883.0         7.50849e7    7.73545e7
#    5 │     1.0      5.0  1.17919e16  1.17919e16       9.10017e5   7.50849e7    7.73545e7
#    6 │     1.0      6.0  1.17919e16  1.17919e16       8.47789e5   7.50849e7    7.73545e7
#    7 │     1.0      7.0  1.17919e16  1.17919e16       8.10974e5   7.50849e7    7.73545e7
#    8 │     1.0      8.0  1.17919e16  1.17919e16       7.97195e5   7.50849e7    7.73545e7
#    9 │     1.0      9.0  1.17919e16  1.17919e16       7.94577e5   7.50849e7    7.73545e7
#   10 │     1.0     10.0  1.17919e16  1.17919e16       7.31641e5   7.50849e7    7.73545e7
#   11 │    10.0      1.0  1.17919e17  1.17919e16       2.91513e6   7.50849e7    7.73545e7
#   12 │     9.0      1.0  1.06127e17  1.17919e16       2.89865e6   7.50849e7    7.73545e7
#   13 │     8.0      1.0  9.43349e16  1.17919e16       2.89865e6   7.50849e7    7.73545e7
#   14 │     7.0      1.0  8.2543e16   1.17919e16       2.883e6     7.50849e7    7.73545e7
#   15 │     6.0      1.0  7.07512e16  1.17919e16       2.84909e6   7.50849e7    7.73545e7
#   16 │     5.0      1.0  5.89593e16  1.17919e16       2.77528e6   7.50849e7    7.73545e7
#   17 │     4.0      1.0  4.71674e16  1.17919e16       2.66897e6   7.50849e7    7.73545e7
#   18 │     3.0      1.0  3.53756e16  1.17919e16       2.62505e6   7.50849e7    7.73545e7
#   19 │     2.0      1.0  2.35837e16  1.17919e16       2.35296e6   7.50849e7    7.73545e7

# %% [markdown]
# ## Stochastic Demand

# %% [markdown]
# ## Parameters in Formulation
#
# - $R$: Set of restaurants (supply nodes).
# - $D$: Set of candidate donation or transshipment centers.
# - $N$: Set of neighborhoods (demand nodes).
# - $S$: Set of demand scenarios.
# - $a_i$: Surplus food available at restaurant $i \in R$.
# - $d_k^s$: Demand at neighborhood $k \in N$ under scenario $s \in S$.
# - $c_{ij}$: Transportation cost (or distance) from restaurant $i$ to center $j$.
# - $c_{jk}$: Transportation cost from center $j$ to neighborhood $k$.
# - $F_j$: Fixed facility-opening cost for center $j \in D$.
# - $p_s$: Probability of scenario $s \in S$.
# - $M$: Penalty coefficient for unmet demand.
# - $\overline{Q}_j$: Capacity parameter linking flow through center $j$ to the binary build decision $z_j$ (big-$M$ type).
#
# ---
#
# ## Formulation: Stochastic Minimum Distance
#
# $$
# \min \quad \sum_{j \in D} F_j z_j + \sum_{s \in S} p_s \left( \sum_{i \in R} \sum_{j \in D} c_{ij} x_{ij}^s + \sum_{j \in D} \sum_{k \in N} c_{jk} y_{jk}^s + M \sum_{k \in N} u_k^s \right)
# $$
#
# **Subject to:**
#
# $$
# \sum_{j \in D} x_{ij}^s \leq a_i \qquad \forall i \in R, \; \forall s \in S
# $$
#
# $$
# \sum_{j \in D} y_{jk}^s + u_k^s = d_k^s \qquad \forall k \in N, \; \forall s \in S
# $$
#
# $$
# \sum_{k \in N} y_{jk}^s = \sum_{i \in R} x_{ij}^s \qquad \forall j \in D, \; \forall s \in S
# $$
#
# $$
# \sum_{i \in R} x_{ij}^s \leq \overline{Q}_j z_j \qquad \forall j \in D, \; \forall s \in S
# $$
#
# $$
# z_j \in \{0, 1\} \qquad \forall j \in D
# $$
#
# $$
# x_{ij}^s, \; y_{jk}^s, \; u_k^s \geq 0 \qquad \forall i \in R, \; \forall j \in D, \; \forall k \in N, \; \forall s \in S
# $$
#
# ---
#
# ## Interpretation of Formulation
#
# Formulation 1 describes a **two-stage stochastic minimum-distance model** in which the planner chooses which donation centers to open (via the binary variables $z_j$) before uncertainty in demand is realized, and then determines optimal food flows for each scenario $s \in S$.
#
# The **objective** minimizes the total expected transportation cost (cost from restaurants to donation centers should probs be equal to cost from donation centers to neighborhoods) plus any unmet-demand penalties, together with fixed opening costs.
#
# **Constraints:**
#
# 1. **First constraint:** Ensures that each restaurant $i$ can send at most its available surplus $a_i$.
#
# 2. **Second constraint:** States that, for each center $j$, the total inflow from restaurants must equal its total outflow to neighborhoods.
#
# 3. **Third constraint:** Enforces that each neighborhood $k$ in scenario $s$ receives food $r_k^s$ equal to the flow from all centers plus any unmet demand $u_k^s$ must satisfy total demand $d_k^s$.
#
# 4. **Fourth constraint:** Links the flows into each center $j$ to its opening decision through the capacity parameter $\overline{Q}_j$, ensuring no flow can pass through a center that is not opened.

# %%
R = nrow(restaurant_data)
D = nrow(food_scrap_locations)
N = nrow(neighborhood_supply[neighborhood_supply.Year .== 2023, :])
Q = sum(restaurant_data.supply)

M = sum(demand)
F = 10000       # Center opening cost

S = 3 # 3 demand years

demand_2023 = neighborhood_supply[neighborhood_supply.Year .== 2023, :].demand
demand_2024 = neighborhood_supply[neighborhood_supply.Year .== 2024, :].demand
demand_2025 = neighborhood_supply[neighborhood_supply.Year .== 2025, :].demand

demand_df = DataFrame(
    y2023 = demand_2023,
    y2024 = demand_2024,
    y2025 = demand_2025
)
# Out:
# 197×3 DataFrame
#  Row │ y2023          y2024           y2025
#      │ Float64        Float64         Float64
# ─────┼──────────────────────────────────────────
#    1 │     0.0             0.0        1.02143e5
#    2 │     0.0             0.0        3.33493e5
#    3 │     0.0             0.0        0.0
#    4 │     0.0             0.0        1.13653e5
#    5 │     0.0             0.0        0.0
#    6 │ 82217.3         13128.3        5.06273e5
#    7 │     2.25651e5       0.0        0.0
#    8 │     9.04474e5       0.0        1.13911e5
#    9 │     0.0             0.0        0.0
#   10 │     1.17086e6       2.4661e6   0.0
#   11 │     0.0             0.0        0.0
#   ⋮  │       ⋮              ⋮             ⋮
#  188 │     0.0             0.0        7.31641e5
#  189 │     0.0             0.0        0.0
#  190 │     0.0             0.0        0.0
#  191 │ 37083.2             0.0        2.28345e6
#  192 │     0.0             0.0        0.0
#  193 │     0.0             0.0        0.0
#  194 │     0.0             0.0        3.11008e5
#  195 │     0.0             0.0        2.33004e6
#  196 │     0.0             0.0        3.43722e6
#  197 │     0.0             0.0        7.97195e5
#                                 176 rows omitted

# %%
println("Total supply: ", sum(supply))
println("Total demand (avg): ", mean([sum(demand_df[:,s]) for s in 1:S]))
println("Supply/Demand ratio: ", sum(supply) / mean([sum(demand_df[:,s]) for s in 1:S]))
# Out:
# Total supply: 7.508486887683786e7
# Total demand (avg): 5.081311007183481e7
# Supply/Demand ratio: 1.4776672549798648

# %%
# Assume you already have:
# R, D, N
# supply (length R), demand (length N)
# cij[i,j], cjk[j,k]
# M defined (big-M for unmet demand)

function build_combined_model(w_cost::Float64, w_eq::Float64)
    model = Model(Gurobi.Optimizer)
    set_silent(model)

    @variable(model, x[s=1:S, 1:R, 1:D] >= 0)   # restaurant -> center
    @variable(model, y[s=1:S, 1:D, 1:N] >= 0)   # center -> neighborhood
    @variable(model, u[s=1:S, 1:N] >= 0)        # unmet demand
    @variable(model, r[s=1:S, 1:N] >= 0)        # received
    @variable(model, t[s=1:S] >= 0)             # worst unmet demand
    @variable(model, z[1:D], Bin)               # center open (first stage)

    # Restaurant supply (optional: could be scenario-dependent if supply changes)
    @constraint(model, [s in 1:S, i in 1:R],
        sum(x[s,i,j] for j in 1:D) <= supply[i]
    )
    
    # Flow conservation at centers
    @constraint(model, [s in 1:S, j in 1:D],
        sum(y[s,j,k] for k in 1:N) == sum(x[s,i,j] for i in 1:R)
    )
    
    # Demand satisfaction
    @constraint(model, [s in 1:S, k in 1:N],
        sum(y[s,j,k] for j in 1:D) + u[s,k] == demand_df[k,s]
    )
    
    # r_k = received
    @constraint(model, [s in 1:S, k in 1:N],
        r[s,k] == sum(y[s,j,k] for j in 1:D)
    )
    
    # r_k ≤ demand
    @constraint(model, [s in 1:S, k in 1:N],
        r[s,k] <= demand_df[k,s]
    )
    
    # Worst unmet demand
    @constraint(model, [s in 1:S, k in 1:N],
        t[s] >= demand_df[k,s] - r[s,k]
    )
    
    # Center capacity constraint (link to first-stage z)
    @constraint(model, [s in 1:S, j in 1:D],
        sum(x[s,i,j] for i in 1:R) <= Q * z[j]
    )


    # === Objective pieces ===
    @objective(model, Min,
        F * sum(z[j] for j in 1:D) +
        sum(1/3 *
            w_cost * (
                sum(cij[i,j] * x[s,i,j] for i in 1:R, j in 1:D) +
                sum(cjk[j,k] * y[s,j,k] for j in 1:D, k in 1:N) +
                M * sum(u[k] for k in 1:N)
                ) +
            w_eq * (
                t[s]
                )
            for s in 1:S)
        )

    return model, x, y, u, r, t, z, w_cost, w_eq
end
# Out:
# build_combined_model (generic function with 1 method)

# %%
model, x, y, u, r, t, z, cost_expr, equity_expr = build_combined_model(1.0, 1.0)
optimize!(model)

obj_val    = objective_value(model)
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Solve the model
model, x, y, u, r, t, cost_expr, equity_expr = build_combined_model(1.0, 1.0)
optimize!(model)

println("=== Summary per Scenario ===")
for s in 1:S
    total_flow_x = sum(value.(x[s, :, :]))
    total_flow_y = sum(value.(y[s, :, :]))
    total_unmet = sum(value.(u[s, :]))
    worst_unmet = value(t[s])
    
    println("Scenario $s:")
    println("  Total flow from restaurants to centers: ", total_flow_x)
    println("  Total flow from centers to neighborhoods: ", total_flow_y)
    println("  Total unmet demand: ", total_unmet)
    println("  Worst unmet demand: ", worst_unmet)
    println("------------------------------------------------")
end

# Total number of centers opened (same for all scenarios)
num_centers_open = sum(value.(z))
println("Total number of centers opened: ", num_centers_open)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# === Summary per Scenario ===
# Scenario 1:
#   Total flow from restaurants to centers: 1.6034409875006376e7
#   Total flow from centers to neighborhoods: 1.6034409875006378e7
#   Total unmet demand: 2.6580457696113624e7
#   Worst unmet demand: 2.882998136e6
# ------------------------------------------------
# Scenario 2:
#   Total flow from restaurants to centers: 1.6034409875006378e7
#   Total flow from centers to neighborhoods: 1.6034409875006376e7
#   Total unmet demand: 4.303078815641451e7
#   Worst unmet demand: 3.62417679513963e6
# ------------------------------------------------
# Scenario 3:
#   Total flow from restaurants to centers: 1.5716457907803938e7
#   Total flow from centers to neighborhoods: 1.5716457907803936e7
#   Total unmet demand: 3.504280670515962e7
#   Worst unmet demand: 1.5469672167837997e6
# ------------------------------------------------
# Total number of centers opened: 111.0

# %% [markdown]
# # Extract the data needed for visualization

# %%
# ============================================================================
# 1. Generate Pareto Frontier (optimized - fewer redundant points)
# ============================================================================
results = DataFrame(
    w_cost = Float64[],
    w_eq = Float64[],
    obj_value = Float64[],
    num_centers = Int[],
    avg_transport_cost = Float64[],
    avg_equity_t = Float64[],
    avg_total_recv = Float64[],
    avg_total_unmet = Float64[],
    t_2023 = Float64[],
    t_2024 = Float64[],
    t_2025 = Float64[]
)

# Streamlined weight pairs (~35 instead of ~100)
# weight_pairs = vcat(
#     [(1.0, w) for w in [0.5, 1.0, 1.5, 2.0, 3.0, 5.0, 8.0, 15.0, 25.0]],  # 9 pts
#     [(w, 1.0) for w in [2.0, 3.0, 5.0, 8.0]],                              # 4 pts
#     [(1.0, w) for w in 4.0:1.0:7.0],                                       # 4 pts - target gap
#     [(2.0, w) for w in 2.0:1.0:6.0],                                       # 5 pts - target gap
#     [(3.0, w) for w in 2.0:1.0:5.0],                                       # 4 pts - target gap
#     [(w, w) for w in [1.5, 2.0, 2.5, 3.0, 4.0]],                          # 5 pts - diagonal
#     [(1.5, w) for w in [3.0, 4.0, 5.0, 6.0]]                              # 4 pts - target gap
# )

# Minimal weight pairs for testing (~10 points)
weight_pairs = [
    (1.0, 0.5),   # cost-focused
    (1.0, 1.0),   # balanced
    (1.0, 2.0),
    (1.0, 5.0),
    (1.0, 10.0),
    (1.0, 20.0),  # equity-focused
    (2.0, 1.0),
    (5.0, 1.0),
    (1.0, 3.0),
    (1.0, 7.0)
]

# Remove duplicates
weight_pairs = unique(weight_pairs)

for (w_cost, w_eq) in weight_pairs
    model, x, y, u, r, t, z, _, _ = build_combined_model(w_cost, w_eq)
    optimize!(model)
    
    termination_status(model) != MOI.OPTIMAL && continue
    
    num_centers = Int(round(sum(value.(z))))
    
    transport_costs = [sum(cij[i,j] * value(x[s,i,j]) for i in 1:R, j in 1:D) +
                       sum(cjk[j,k] * value(y[s,j,k]) for j in 1:D, k in 1:N) for s in 1:S]
    
    total_recvs = [sum(value.(r[s,:])) for s in 1:S]
    total_unmets = [sum(value.(u[s,:])) for s in 1:S]
    equity_ts = [value(t[s]) for s in 1:S]
    
    push!(results, (
        w_cost, w_eq,
        objective_value(model),
        num_centers,
        mean(transport_costs),
        mean(equity_ts),
        mean(total_recvs),
        mean(total_unmets),
        equity_ts[1], equity_ts[2], equity_ts[3]
    ))
end

CSV.write("viz_data/pareto_results.csv", results)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# "viz_data/pareto_results.csv"

# %%
# ============================================================================
# 2. Export Location Data
# ============================================================================
CSV.write("viz_data/restaurants.csv", DataFrame(
    id = 1:R,
    latitude = restaurant_data.latitude,
    longitude = restaurant_data.longitude,
    supply = restaurant_data.supply
))

CSV.write("viz_data/donation_centers.csv", DataFrame(
    id = 1:D,
    latitude = food_scrap_locations.latitude,
    longitude = food_scrap_locations.longitude
))

# Update the neighborhoods export to include names
# Reload original neighborhood data to get names
neighborhood_full = CSV.read(neighborhood_path, DataFrame)
nbhd_2023_full = neighborhood_full[neighborhood_full.Year .== 2023, :]

# Export neighborhoods with names
CSV.write("viz_data/neighborhoods.csv", DataFrame(
    id = 1:N,
    name = nbhd_2023_full[!, "Neighborhood.Tabulation.Area..NTA..Name"],
    latitude = nbhd_2023_full.latitude,
    longitude = nbhd_2023_full.longitude,
    demand_2023 = demand_df.y2023,
    demand_2024 = demand_df.y2024,
    demand_2025 = demand_df.y2025
))

# ============================================================================
# 3. Export Scenario-Specific Results for a Balanced Solution
# ============================================================================
model_bal, x_bal, y_bal, u_bal, r_bal, t_bal, z_bal, _, _ = build_combined_model(1.0, 3.0)
optimize!(model_bal)

if termination_status(model_bal) == MOI.OPTIMAL
    # Centers opened
    CSV.write("viz_data/centers_opened.csv", DataFrame(
        id = 1:D,
        opened = Int.(round.(value.(z_bal)))
    ))
    
    # Per-scenario allocations
    for s in 1:S
        year = 2022 + s
        CSV.write("viz_data/allocations_$year.csv", DataFrame(
            neighborhood_id = 1:N,
            received = value.(r_bal[s,:]),
            unmet = value.(u_bal[s,:])
        ))
    end
    
    # Flows for scenario 1 (2023)
    flows = DataFrame(from_type=String[], from_id=Int[], to_type=String[], to_id=Int[], flow=Float64[])
    for i in 1:R, j in 1:D
        value(x_bal[1,i,j]) > 1e-3 && push!(flows, ("restaurant", i, "center", j, value(x_bal[1,i,j])))
    end
    for j in 1:D, k in 1:N
        value(y_bal[1,j,k]) > 1e-3 && push!(flows, ("center", j, "neighborhood", k, value(y_bal[1,j,k])))
    end
    CSV.write("viz_data/flows_2023.csv", flows)
end

# ============================================================================
# 4. Export Scenario Comparison Data
# ============================================================================
scenario_summary = DataFrame(
    scenario = ["2023", "2024", "2025"],
    total_demand = [sum(demand_df.y2023), sum(demand_df.y2024), sum(demand_df.y2025)],
    total_received = [sum(value.(r_bal[s,:])) for s in 1:S],
    total_unmet = [sum(value.(u_bal[s,:])) for s in 1:S],
    worst_unmet = [value(t_bal[s]) for s in 1:S]
)
CSV.write("viz_data/scenario_summary.csv", scenario_summary)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# "viz_data/scenario_summary.csv"

# %%
# ============================================================================
# 5. Export Allocations for ALL Pareto Solutions (for animation)
# ============================================================================
mkpath("viz_data/pareto_allocations")

for (idx, (w_cost, w_eq)) in enumerate(weight_pairs)
    model, x, y, u, r, t, z, _, _ = build_combined_model(w_cost, w_eq)
    optimize!(model)
    
    termination_status(model) != MOI.OPTIMAL && continue
    
    # Average unmet across scenarios
    avg_unmet = [mean([value(u[s,k]) for s in 1:S]) for k in 1:N]
    
    CSV.write("viz_data/pareto_allocations/alloc_$(idx).csv", DataFrame(
        neighborhood_id = 1:N,
        avg_unmet = avg_unmet
    ))
end

println("Exported $(length(weight_pairs)) allocation files")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Set parameter Username
# Set parameter LicenseID to value 2702779
# Academic license - for non-commercial use only - expires 2026-09-03
# Exported 32 allocation files
